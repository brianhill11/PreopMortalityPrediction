# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Remove-duplicate-rows" data-toc-modified-id="Remove-duplicate-rows-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Remove duplicate rows</a></span></li></ul></li><li><span><a href="#if-multiple-surgeries-for-a-single-ADMSN_ID,-take-first-surgery" data-toc-modified-id="if-multiple-surgeries-for-a-single-ADMSN_ID,-take-first-surgery-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>if multiple surgeries for a single ADMSN_ID, take first surgery</a></span><ul class="toc-item"><li><span><a href="#Create-outcomes-data-frame" data-toc-modified-id="Create-outcomes-data-frame-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Create outcomes data frame</a></span></li><li><span><a href="#Check-frequency-of-target-variables" data-toc-modified-id="Check-frequency-of-target-variables-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Check frequency of target variables</a></span></li><li><span><a href="#Join-Main-data-frame-with-outcomes-using-ADMSN_ID-as-key" data-toc-modified-id="Join-Main-data-frame-with-outcomes-using-ADMSN_ID-as-key-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Join Main data frame with outcomes using ADMSN_ID as key</a></span></li></ul></li><li><span><a href="#Use-PRED_ASA_STATUS-as-a-feature" data-toc-modified-id="Use-PRED_ASA_STATUS-as-a-feature-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Use PRED_ASA_STATUS as a feature</a></span></li><li><span><a href="#Use-Charlson-comorbidity-as-an-input-feature" data-toc-modified-id="Use-Charlson-comorbidity-as-an-input-feature-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Use Charlson comorbidity as an input feature</a></span></li><li><span><a href="#Use-POSPOM-score-as-an-input-feature" data-toc-modified-id="Use-POSPOM-score-as-an-input-feature-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Use POSPOM score as an input feature</a></span><ul class="toc-item"><li><span><a href="#Check-number-of-null-values-for-each-feature" data-toc-modified-id="Check-number-of-null-values-for-each-feature-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Check number of null values for each feature</a></span></li></ul></li><li><span><a href="#Filter-out-surgeries-that-don't-occur-in-RR-or-SM-operating-rooms" data-toc-modified-id="Filter-out-surgeries-that-don't-occur-in-RR-or-SM-operating-rooms-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Filter out surgeries that don't occur in RR or SM operating rooms</a></span><ul class="toc-item"><li><span><a href="#Filter-out-surgeries-that-were-not-INPATIENT,-SAME-DAY-ADMIT,-EMERGENCY,-or-OVERNIGHT-RECOVERY" data-toc-modified-id="Filter-out-surgeries-that-were-not-INPATIENT,-SAME-DAY-ADMIT,-EMERGENCY,-or-OVERNIGHT-RECOVERY-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Filter out surgeries that were not INPATIENT, SAME DAY ADMIT, EMERGENCY, or OVERNIGHT RECOVERY</a></span></li><li><span><a href="#Filter-based-on-ASA_STATUS,-AGE" data-toc-modified-id="Filter-based-on-ASA_STATUS,-AGE-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Filter based on ASA_STATUS, AGE</a></span></li><li><span><a href="#Check-demographic-distributions" data-toc-modified-id="Check-demographic-distributions-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Check demographic distributions</a></span></li><li><span><a href="#Remove-outlier-values" data-toc-modified-id="Remove-outlier-values-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Remove outlier values</a></span></li></ul></li><li><span><a href="#Remove-variables-related-to-lab-times-(i.e.-*.HRS_2_SURGERY)" data-toc-modified-id="Remove-variables-related-to-lab-times-(i.e.-*.HRS_2_SURGERY)-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Remove variables related to lab times (i.e. *.HRS_2_SURGERY)</a></span></li><li><span><a href="#Remove-unnecessary-features" data-toc-modified-id="Remove-unnecessary-features-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Remove unnecessary features</a></span><ul class="toc-item"><li><span><a href="#Plot-feature-correlation" data-toc-modified-id="Plot-feature-correlation-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Plot feature correlation</a></span></li><li><span><a href="#One-hot-encode-categorical-variables" data-toc-modified-id="One-hot-encode-categorical-variables-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>One-hot encode categorical variables</a></span></li><li><span><a href="#Remove-features-we-don't-want-to-include" data-toc-modified-id="Remove-features-we-don't-want-to-include-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Remove features we don't want to include</a></span></li><li><span><a href="#Remove-target-variables-from-data-frame" data-toc-modified-id="Remove-target-variables-from-data-frame-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Remove target variables from data frame</a></span></li><li><span><a href="#Impute-missing-data" data-toc-modified-id="Impute-missing-data-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Impute missing data</a></span></li><li><span><a href="#Split-data-into-training,-testing-sets" data-toc-modified-id="Split-data-into-training,-testing-sets-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Split data into training, testing sets</a></span></li><li><span><a href="#Standardize-training,-testing-data" data-toc-modified-id="Standardize-training,-testing-data-7.7"><span class="toc-item-num">7.7&nbsp;&nbsp;</span>Standardize training, testing data</a></span></li><li><span><a href="#Train-model(s)" data-toc-modified-id="Train-model(s)-7.8"><span class="toc-item-num">7.8&nbsp;&nbsp;</span>Train model(s)</a></span></li><li><span><a href="#Examine-feature-relevance" data-toc-modified-id="Examine-feature-relevance-7.9"><span class="toc-item-num">7.9&nbsp;&nbsp;</span>Examine feature relevance</a></span></li><li><span><a href="#Generate-class-probabilities" data-toc-modified-id="Generate-class-probabilities-7.10"><span class="toc-item-num">7.10&nbsp;&nbsp;</span>Generate class probabilities</a></span></li><li><span><a href="#Predict-class-labels-&amp;-plot-mean-square-error" data-toc-modified-id="Predict-class-labels-&amp;-plot-mean-square-error-7.11"><span class="toc-item-num">7.11&nbsp;&nbsp;</span>Predict class labels &amp; plot mean square error</a></span></li><li><span><a href="#Calculate-accuracy-and-AUC" data-toc-modified-id="Calculate-accuracy-and-AUC-7.12"><span class="toc-item-num">7.12&nbsp;&nbsp;</span>Calculate accuracy and AUC</a></span></li><li><span><a href="#Plot-ROC-curve" data-toc-modified-id="Plot-ROC-curve-7.13"><span class="toc-item-num">7.13&nbsp;&nbsp;</span>Plot ROC curve</a></span></li><li><span><a href="#Plot-precision-recall-curve" data-toc-modified-id="Plot-precision-recall-curve-7.14"><span class="toc-item-num">7.14&nbsp;&nbsp;</span>Plot precision-recall curve</a></span></li><li><span><a href="#Plot-calibration-curves" data-toc-modified-id="Plot-calibration-curves-7.15"><span class="toc-item-num">7.15&nbsp;&nbsp;</span>Plot calibration curves</a></span></li></ul></li><li><span><a href="#Calculate-Brier-Score-Loss" data-toc-modified-id="Calculate-Brier-Score-Loss-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Calculate Brier Score Loss</a></span><ul class="toc-item"><li><span><a href="#Cross-Validation-of-Model-Metrics" data-toc-modified-id="Cross-Validation-of-Model-Metrics-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Cross Validation of Model Metrics</a></span></li></ul></li></ul></div>

# %%
import os
import sys
import re
from tempfile import mkdtemp
import hashlib

print(sys.version_info)

home_dir = os.getenv("HOME")
print(os.getenv("PYTHONPATH"))

import numpy as np
import pickle
from numpy.linalg import svd
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split, GroupKFold
from sklearn.linear_model import LogisticRegression, ElasticNet, ElasticNetCV, ARDRegression, SGDClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics, tree
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, Imputer, LabelEncoder
from sklearn.metrics import precision_recall_curve, average_precision_score, brier_score_loss, make_scorer
from sklearn.model_selection import cross_validate, cross_val_predict, GridSearchCV, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.calibration import calibration_curve, CalibratedClassifierCV
from sklearn.externals import joblib
from sklearn.base import BaseEstimator, TransformerMixin
from scipy.stats import mstats
import scipy.stats as st
from IPython.display import display, HTML

from fancyimpute import SoftImpute, KNN, MICE
from ehr_utils import *
from imblearn.over_sampling import SMOTE, ADASYN
from imblearn.under_sampling import NearMiss
from imblearn.pipeline import Pipeline
from xgboost import XGBClassifier, XGBRegressor, plot_tree
#import shap
#from predictive_imputer import predictive_imputer

# from keras.models import model_from_json, Sequential
# from keras.layers import Dense, Dropout
# from keras.wrappers.scikit_learn import KerasClassifier
# from keras.optimizers import SGD
# Out:
# sys.version_info(major=2, minor=7, micro=15, releaselevel='final', serial=0)
# None

# %%
#pandas2ri.activate()
# %matplotlib inline
pd.set_option('display.max_rows', 2000)
pd.set_option('display.max_columns', 100)
# colours for plotting for BJA
COLOUR_1 = "#006BFA" # blue
COLOUR_2 = "#378E00" # green
COLOUR_3 = "#E64DFF" # pink
COLOUR_4 = "#FF8000" # gold
COLOUR_5 = "#33FFFF" # light blue
COLOUR_6 = "#FF3300" # orange
PLOT_COLOURS = [COLOUR_1, COLOUR_2, COLOUR_3, COLOUR_4, COLOUR_5, COLOUR_6]
# DPI for figures
fig_dpi = 1200

data_dir="/data/DataNov21_2017"
ccs_icd_mapping_f="/home/blhill/external_data/ccs_dx_icd10cm_2018_1.csv"

# main_f = os.path.join(data_dir, "Main_Data.txt")
# outcomes_f = os.path.join(data_dir, "Outcomes_Data.txt")
# icd_codes_f = os.path.join(data_dir, "ICD9_10Codes.txt")
# main_filtered_f = "Main_Data_filtered.txt"
# main_filtered_working_f = "Main_Data_filtered.working.txt"
asa_predictions_f = "paper/asa_imp/ASA_predictions_noTime.txt"
comorbid_f = "charlson_quan_comorbid.txt"
pospom_f = "/opt/genomics/workingdir/blhill/POSPOM_scores.txt"
#main_filtered_f = main_f
main_filtered_f = "/opt/genomics/workingdir/blhill/main_merged_w_akin_spo2.filtered.main.txt"
test_or_case_id_f = "/opt/genomics/workingdir/blhill/or_case_id_032018.txt"

# changing the exp_prefix directory below decides which features to load
# and where to save output files
exp_prefix = "pospom"
dir_to_save_files = os.path.join("paper/", exp_prefix)
if not os.path.exists(dir_to_save_files):
    os.makedirs(dir_to_save_files)

# set to False to hide IDs    
verbose = False
# default size for plots
default_size=(8,8)
# model type == "regression" || "classification"
model_type = "classification"
# AKIN stage > AKIN_THRESHOLD considered an AKIN_EVENT
AKIN_THRESHOLD=1
# data points measured after this time will be discarded
TIME_THRESHOLD=-60*24*0
# if True, subsample to ensure classes are split 50/50
USE_EQUAL_CLASS_FREQ=False
CLASS_MULTIPLIER=1.0

MIN_ASA_STATUS=1
MAX_ASA_STATUS=5
MIN_AGE=18
MAX_AGE=89

## this variable is the column that we will use as the target variable for the model
TARGET_VARIABLE = 'INPT_DEATH_YN'
#TARGET_VARIABLE = 'AKIN_STAGE1_YN'
#TARGET_VARIABLE = 'MAX_AKIN_STAGE'
#TARGET_VARIABLE = 'AKIN_EVENT'
#TARGET_VARIABLE = 'FLOOR_2_ICU_YN'
#TARGET_VARIABLE = "ASA_STATUS"

# NOTE: feature_whitelist should have HCUP_CODE,  in it
feature_whitelist = ["OR_CASE_ID", "ASA_STATUS", "LAST_EF_RESTING", "LAST_EF_STRESSED", 
                     "LAST_EF_YN", "ADULT_MDRD_GFR_WHT", "ASA_RVU", "AGE_LT_90",
                    'PATIENT_CLASS_INPATIENT', 'PATIENT_CLASS_OVERNIGHT RECOVERY', 'PATIENT_CLASS_SAME DAY ADMIT']
feature_whitelist2 = ["GENDER", "LOCATION_GROUP", "WEIGHT_KG", "HEIGHT_IN", "BMI"]
feature_whitelist3 = ["PREOP_CR_VAL", "DURATION_MINUTE"]

asa_pred_features = ["OR_CASE_ID", 'AGE_LT_89', 'BICARBONATE', 'CHLORIDE','CREATININE', 'GLUCOSE','HEMOGLOBIN','INR',
 'PLATELET.COUNT', 'PROTHROMBIN.TIME', 'POTASSIUM','SODIUM', 'UREA.NITROGEN', 'WHITE.BLOOD.CELL.COUNT',
 'ALBUMIN','ALKALINE.PHOSPHATASE', 'ALT','AST', 'BNP','BILIRUBIN.TOTAL', 'SYS.BLOOD.PRESSURE',
 'DIAS.BLOOD.PRESSURE', 'SYS.PAP','DIAS.PAP', 'PULSE', 'SPO2', 'GENDER_M','HEIGHT_IN','WEIGHT_KG','BMI']
asa_pred_features += ['ECHO.EF'] # this feature likely unique to UCLA 

# same as above but including time now
asa_pred_features = ['OR_CASE_ID','AGE_LT_89','BICARBONATE',
 'BICARBONATE.HRS_2_SURGERY', 'CHLORIDE', 'CHLORIDE.HRS_2_SURGERY',
 'CREATININE', 'CREATININE.HRS_2_SURGERY', 'GLUCOSE', 'GLUCOSE.HRS_2_SURGERY',
 'HEMOGLOBIN', 'HEMOGLOBIN.HRS_2_SURGERY', 'INR', 'INR.HRS_2_SURGERY',
 'PLATELET.COUNT', 'PLATELET.COUNT.HRS_2_SURGERY', 'PROTHROMBIN.TIME',
 'PROTHROMBIN.TIME.HRS_2_SURGERY', 'POTASSIUM', 'POTASSIUM.HRS_2_SURGERY',
 'SODIUM', 'SODIUM.HRS_2_SURGERY', 'UREA.NITROGEN',
 'UREA.NITROGEN.HRS_2_SURGERY', 'WHITE.BLOOD.CELL.COUNT',
 'WHITE.BLOOD.CELL.COUNT.HRS_2_SURGERY', 'ALBUMIN', 'ALBUMIN.HRS_2_SURGERY',
 'ALKALINE.PHOSPHATASE', 'ALKALINE.PHOSPHATASE.HRS_2_SURGERY', 'ALT',
 'ALT.HRS_2_SURGERY', 'AST', 'AST.HRS_2_SURGERY', 'BNP', 'BNP.HRS_2_SURGERY',
 'BILIRUBIN.TOTAL', 'BILIRUBIN.TOTAL.HRS_2_SURGERY', 'SYS.BLOOD.PRESSURE',
 'DIAS.BLOOD.PRESSURE', 'BLOOD.PRESSURE.HRS_2_SURGERY', 'SYS.PAP', 'DIAS.PAP',
 'PAP.HRS_2_SURGERY', 'PULSE', 'PULSE.HRS_2_SURGERY', 'SPO2',
 'SPO2.HRS_2_SURGERY',
 'GENDER_M', 'HEIGHT_IN', 'WEIGHT_KG', 'BMI']
asa_pred_features += ['ECHO.EF','ECHO.EF.HRS_2_SURGERY'] # this feature likely unique to UCLA 


# features to remove when predicting death using predictedASA
asa_pred_features_to_drop = ['BICARBONATE', 'CHLORIDE','CREATININE', 'GLUCOSE','HEMOGLOBIN','INR',
 'PLATELET.COUNT', 'PROTHROMBIN.TIME', 'POTASSIUM','SODIUM', 'UREA.NITROGEN', 'WHITE.BLOOD.CELL.COUNT',
 'ALBUMIN','ALKALINE.PHOSPHATASE', 'ALT','AST', 'BNP','BILIRUBIN.TOTAL', 'SYS.BLOOD.PRESSURE',
 'DIAS.BLOOD.PRESSURE', 'SYS.PAP','DIAS.PAP', 'PULSE', 'SPO2', 'ECHO.EF']

feature_whitelist += feature_whitelist2
#feature_whitelist = ["ASA_STATUS", "PREOP_CR_VAL", "ASA_RVU", 'PATIENT_CLASS_INPATIENT', 'PATIENT_CLASS_OVERNIGHT RECOVERY', 'PATIENT_CLASS_SAME DAY ADMIT']
#feature_whitelist = ["OR_CASE_ID", "ASA_STATUS"]
#feature_whitelist = ["OR_CASE_ID", "PRED_ASA_STATUS"]
#feature_whitelist = ["OR_CASE_ID", "CHARLSON"]
feature_whitelist = []
#feature_whitelist = asa_pred_features

df = pd.read_csv(main_filtered_f,sep="|")
print df.shape
#display(df.PATIENT_CLASS.unique())
print len(df.columns)
if verbose:
    display(df.iloc[0:20, :])

def get_sha256_hash(x):
    m = hashlib.sha256()
    m.update(str(x))
    return m.hexdigest().upper()
df["OR_CASE_ID"] = df["OR_CASE_ID"].apply(get_sha256_hash)
    
# make sure binary columns are set to True/False
try:
    df.NITRIC_OXIDE = df.NITRIC_OXIDE.astype(bool)
    df.ART_LINE = df.ART_LINE.astype(bool)
    df.PA_CATHETER = df.PA_CATHETER.astype(bool)
except AttributeError:
    pass
if verbose:
    display(df.describe(include="all"))
ids = df["ADMSN_ID"]
#display(df[ids.isin(ids[ids.duplicated()])].head(30))
# display(df[df["INPT_DEATH_YN"] == True].sort_values(by=["ADMSN_ID", "HRS_ADMSN_TO_SURGERY"]).head(30))
# Out:
# (82237, 109)
# 109

# %%
# get list of surgeries for testing
test_or_case_ids = pd.read_csv(test_or_case_id_f, header=None)

# %%
# print df["_merge"].unique()
# print df["AGE_LT_90"].isnull().sum()
# print df[df["_merge"] == 'both'].shape
# print df.INPT_DEATH_YN.mean()
# df2 = pd.read_csv("Main_Data_filtered.txt", sep="\t")
# print df2.shape

# print df.shape
# print df[df.OR_CASE_ID.isin(df2.OR_CASE_ID)].shape
# print df[df.OR_CASE_ID.isin(df2.OR_CASE_ID)].INPT_DEATH_YN.mean()

# df2.drop_duplicates(inplace=True)
# print df2["AGE_LT_89"].isnull().sum()
# # df2.sort_values(by=["ADMSN_ID", "HRS_ADMSN_TO_SURGERY"], inplace=True)
# # df2.drop_duplicates(subset="ADMSN_ID", keep="first", inplace=True)
# # df2 = df2[df2['PAT_CLASS'].isin(['INPATIENT', 'SAME DAY ADMIT', 'EMERGENCY', 'OVERNIGHT RECOVERY'])]
# #df2 = df2[df2['LOCATION_GROUP'].isin(['RR OR', 'SM OR', 'SM SC'])]
# #df2 = df2[(df2["AGE_LT_89"] <= MAX_AGE) & (df2["AGE_LT_89"] >= MIN_AGE)]
# print df2.shape
# print df2.INPT_DEATH_YN.mean()

# outcomes_df = pd.read_csv(os.path.join(data_dir, "Outcomes_Data.txt"), sep='|', header=0)

# old_df = pd.read_csv("Main_Data_filtered.working.txt",sep="\t")
# print "old.df shape:", old_df.shape
# old_df.drop_duplicates(inplace=True)
# print old_df["AGE_LT_90"].isnull().sum()
# #df.drop(['INPT_DEATH_YN'], axis=1, inplace=True)
# # old_df = old_df[old_df["ADMSN_SURGERY_NUMBER"] == 1]
# # old_df = old_df[old_df["ANES_CASE_YN"] == 1]
# #old_df = old_df[(old_df["AGE_LT_90"] <= MAX_AGE) & (old_df["AGE_LT_90"] >= MIN_AGE)]
# # old_df = old_df[old_df['PATIENT_CLASS'].isin(['INPATIENT', 'SAME DAY ADMIT', 'EMERGENCY', 'OVERNIGHT RECOVERY'])]
# print old_df.shape
# old_df = old_df.merge(outcomes_df, on="ADMSN_ID", how="inner")
# print "shape after merging outcomes:", old_df.shape
# print "old df mean:", old_df.INPT_DEATH_YN.mean()

# df2 = df2.merge(old_df[["OR_CASE_ID", "GENDER", "HEIGHT_IN", "WEIGHT_KG", "BMI", "ASA_STATUS", "ADMSN_SURGERY_NUMBER"]], on="OR_CASE_ID", how="inner")
# print "merged shape:", df2.shape
# print df2[~df2.OR_CASE_ID.isin(old_df.OR_CASE_ID)].shape
# print df2[~df2.OR_CASE_ID.isin(old_df.OR_CASE_ID)].INPT_DEATH_YN.mean()

# if verbose:
#     display(df2.head())

# %%
FEATURES_PATH = os.path.join(dir_to_save_files, 'EHR_MAIN_FEATURES.csv')
features_df = pd.read_csv(FEATURES_PATH)

features_dict = {name:list(col.dropna()) for name,col in features_df.items()}
print(features_dict.keys())

final_features = features_dict['final_features']
cat_to_drop = features_dict['cat_to_drop']
outcome_vars = features_dict['outcome_vars']
feat_to_drop = features_dict['feat_to_drop']
cat_vars = features_dict['cat_vars']
contin_vars = features_dict['contin_vars']
bool_outcome_vars = features_dict['bool_outcome_vars']
# Out:
# ['final_features', 'outcome_vars', 'contin_vars', 'cat_vars', 'feat_to_drop', 'cat_to_drop', 'bool_outcome_vars']

# %% [markdown]
# ## Remove duplicate rows

# %%
# remove any people that had multiple surgeries
print df.shape
display(df[TARGET_VARIABLE].mean())
# drop any rows that are exact copies of another row
df.drop_duplicates(inplace=True)
print df.shape
# Out:
# (82237, 109)
# 0.023213395430280774
# (82237, 109)

# %%
#ids = df["ADMSN_ID"]
# display(df[ids.isin(ids[ids.duplicated()]) & (df["INPT_DEATH_YN"] == True)].sort_values(by=["ADMSN_ID", "HRS_ADMSN_TO_SURGERY"]).head(30))
# display(df[ids.isin(ids[ids.duplicated()]) & (df["INPT_DEATH_YN"] == True)].sort_values(by=["ADMSN_ID", "HRS_ADMSN_TO_SURGERY"]).groupby("ADMSN_ID").apply(lambda x: x.corr()).head(30))
# display(df["INPT_DEATH_YN"].mean())
# display(df[df["INPT_DEATH_YN"] == True & df["HCUP_CODE"].isnull()].head(300))

#display(df[df["INPT_DEATH_YN"] == True].head(300))

# %% [markdown]
# # if multiple surgeries for a single ADMSN_ID, take first surgery

# %%
# if multiple surgeries for a single ADMSN_ID, take first surgery
# print df.shape
# df.sort_values(by=["ADMSN_ID", "HRS_ADMSN_TO_SURGERY"], inplace=True)
# df.drop_duplicates(subset="ADMSN_ID", keep="first", inplace=True)
# display(df["INPT_DEATH_YN"].mean())
# print df.shape
# display(df.describe(include="all"))

# %%
print len(df.CASE_SRV_NAME.unique())
print len(df.CASE_SRV_NAME_GROUP.unique())
# Out:
# 40
# 29

# %% [markdown]
# ## Create outcomes data frame

# %%
# create data frame for outcomes table
# print outcomes_f
# outcomes_df = pd.read_csv(outcomes_f, sep='|', header=0)
# outcomes_df.INPT_DEATH_YN = outcomes_df.INPT_DEATH_YN.astype(bool)
# outcomes_df.AKIN_STAGE1_YN = outcomes_df.AKIN_STAGE1_YN.apply(lambda x: True if x == 1 else False)
# outcomes_df.AKIN_STAGE2_YN = outcomes_df.AKIN_STAGE2_YN.apply(lambda x: True if x == 1 else False)
# outcomes_df.AKIN_STAGE3_YN = outcomes_df.AKIN_STAGE3_YN.apply(lambda x: True if x == 1 else False)
# outcomes_df.POSTOP_REINTUBATION_YN = outcomes_df.POSTOP_REINTUBATION_YN.astype(bool)
# outcomes_df.ADMSN_TRACH_YN = outcomes_df.ADMSN_TRACH_YN.apply(lambda x: True if x == 1 else False)
# outcomes_df.FLOOR_2_ICU_YN = outcomes_df.FLOOR_2_ICU_YN.astype(bool)
# create new feature AKIN_EVENT, true if MAX_AKIN_STAGE > AKIN_THRESHOLD else false
df[TARGET_VARIABLE] = df[TARGET_VARIABLE].astype(bool)
df['AKIN_EVENT'] = df['MAX_AKIN_STAGE'].apply(lambda val: True if val > AKIN_THRESHOLD else False)
# display(outcomes_df.describe(include="all"))

# %% [markdown]
# ## Check frequency of target variables

# %%
# bool_outcome_vars = ['INPT_DEATH_YN', 'AKIN_STAGE1_YN', 'AKIN_STAGE2_YN', 'AKIN_STAGE3_YN', 'POSTOP_REINTUBATION_YN', 
#                      'ADMSN_TRACH_YN', 'FLOOR_2_ICU_YN', 'AKIN_EVENT']

display(df[bool_outcome_vars].mean())
# Out:
# INPT_DEATH_YN             0.023213
# AKIN_STAGE1_YN            0.158663
# AKIN_STAGE2_YN            0.040566
# AKIN_STAGE3_YN            0.055073
# POSTOP_REINTUBATION_YN    0.051035
# ADMSN_TRACH_YN            0.364459
# FLOOR_2_ICU_YN            0.059608
# dtype: float64

# %% [markdown]
# ## Join Main data frame with outcomes using ADMSN_ID as key
#
# To add/remove ASA_STATUS from the model, add/remove "ASA_STATUS" from the list of columns below
# To get the number of patients in RR OR/SM OR, add "LOCATION_GROUP" to list of columns below

# %%
# print df.shape
# old_df = pd.read_csv(main_filtered_working_f,sep="\t")
# print old_df.shape
# #df = df.merge(old_df[["ADMSN_ID", "GENDER"]], on="ADMSN_ID", how="inner")
# # removed 
# df = df.merge(old_df[["OR_CASE_ID", "GENDER", "HEIGHT_IN", "WEIGHT_KG", "BMI", "ASA_STATUS", "ADMSN_SURGERY_NUMBER"]], on="OR_CASE_ID", how="inner")
# print df.shape

# %% [markdown]
# # Use PRED_ASA_STATUS as a feature
#
# To use PRED_ASA_STATUS as a feature in the model, uncomment out the block of code below

# %%
if "imp_asa" in exp_prefix:
    print df.shape
    asa_df = pd.read_csv(asa_predictions_f, sep="\t")
    print "asa_df shape:", asa_df.shape
    asa_df.drop_duplicates(inplace=True)
    #asa_df.drop_duplicates(subset="ADMSN_ID", keep="first", inplace=True)
    print "asa_df shape after dedup:", asa_df.shape
    df = df.merge(asa_df[["OR_CASE_ID", "PRED_ASA_STATUS"]], on="OR_CASE_ID", how="inner")
    print df.shape
    df.drop_duplicates(inplace=True)
    print df.shape
    # df.drop(asa_pred_features_to_drop, axis=1, inplace=True)
    # print df.shape
    if verbose:
        df.head(20)

# %% [markdown]
# # Use Charlson comorbidity as an input feature

# %%
if exp_prefix == "charlson": 
    print df.shape
    comorbid_df = pd.read_csv(comorbid_f, sep="\t")
    comorbid_df.columns = ["ADMSN_ID", "CHARLSON"]
    print "asa_df shape:", comorbid_df.shape
    comorbid_df.drop_duplicates(inplace=True)
    comorbid_df.drop_duplicates(subset="ADMSN_ID", keep="first", inplace=True)
    print "comorbid_df shape after dedup:", comorbid_df.shape
    df = df.merge(comorbid_df[["ADMSN_ID", "CHARLSON"]], on="ADMSN_ID", how="left")
    print df.shape
    df.drop_duplicates(inplace=True)
    print df.shape
    # df.drop(asa_pred_features_to_drop, axis=1, inplace=True)
    # print df.shape
    #df.head(20)
    if verbose:
        df.describe(include="all")

# %% [markdown]
# # Use POSPOM score as an input feature

# %%
if exp_prefix == "pospom": 
    print df.shape
    pospom_df = pd.read_csv(pospom_f, sep=",", header=0)
    print "pospom_df shape:", pospom_df.shape
    pospom_df.drop_duplicates(inplace=True)
    # add surgical POSPOM score to diagnosis POSPOM score
    #pospom_df["POSPOM"] = pospom_df["SURGICAL_POSPOM_COMPONENT"] + pospom_df["POSPOM_SCORE"]
    print(pospom_df["SURGICAL_POSPOM_COMPONENT"].isna().mean())
    print(pospom_df["POSPOM_SCORE"].isna().mean())
    
    pospom_df["OR_CASE_ID"] = pospom_df["OR_CASE_ID"].apply(get_sha256_hash)
    
    pospom_df["POSPOM_SCORE"].fillna(0, inplace=True)
    print(pospom_df["POSPOM_SCORE"].isna().mean())
    #pospom_df["POSPOM"] = pospom_df["SURGICAL_POSPOM_COMPONENT"]
    pospom_df["POSPOM"] = pospom_df["SURGICAL_POSPOM_COMPONENT"] + pospom_df["POSPOM_SCORE"]
    #pospom_df.drop(["SURGICAL_POSPOM_COMPONENT", "POSPOM_SCORE"], axis=1, inplace=True)
    pospom_df.drop(["POSPOM_SCORE"], axis=1, inplace=True)
    #pospom_df.drop_duplicates(subset="ADMSN_ID", keep="first", inplace=True)
    print "pospom_df shape after dedup:", pospom_df.shape
    print(pospom_df.head())
    df = df.merge(pospom_df, on="OR_CASE_ID", how="left")
    print df.shape
    df.drop_duplicates(inplace=True)
    print df.shape
    print(df["SURGICAL_POSPOM_COMPONENT"].value_counts()/df.shape[0])
    df["SURGICAL_POSPOM_COMPONENT"].hist(bins=20)
    #df["POSPOM"].hist(bins=20)
    plt.show()
    # df.drop(asa_pred_features_to_drop, axis=1, inplace=True)
    # print df.shape
    #df.head(20)
    if verbose:
        df.describe(include="all")
# Out:
# (82237, 110)
# pospom_df shape: (412903, 3)
# 0.0
# 0.0288615001586329
# 0.0
# pospom_df shape after dedup: (412903, 3)
#                                           OR_CASE_ID  \
# 0  576D85A2A756E8B7E72EC774ABCD8534D10549B50EF425...
# 1  994DDD6F8C20E51B6265DA3602DBFB18166156AD3D1B26...
# 2  706A6ABDD16F4B9C7FEA83D9AADC8637A6FCF6D0824710...
# 3  4F2CDD7EC7DCF19CC47B31B2BB7AD59F7239B144C3B7D0...
# 4  27743FC80739C3DF433DC26D18E8F44B5A13559C7E68F1...
#
#    SURGICAL_POSPOM_COMPONENT  POSPOM
# 0                         17    27.0
# 1                         12    26.0
# 2                         12    25.0
# 3                         17    31.0
# 4                         17    17.0
# (82237, 112)
# (82237, 112)
# 12    0.201199
# 6     0.179250
# 16    0.170787
# 9     0.166105
# 15    0.091808
# 17    0.065785
# 13    0.064557
# 8     0.026667
# 22    0.019651
# 14    0.014191
# Name: SURGICAL_POSPOM_COMPONENT, dtype: float64

# %%
# # join main data frame with outcomes data
# df.drop(['INPT_DEATH_YN'], axis=1, inplace=True)
# df = df.merge(outcomes_df, on="ADMSN_ID", how="inner")
# print "Column names:", df.columns.values
# print "df shape:", df.shape

# display(df[bool_outcome_vars].mean())
# display(df.describe(include="all"))

# %% [markdown]
# ## Check number of null values for each feature

# %%
# get count of null values in each column
print df.isnull().sum()/df.shape[0]
plt.figure(figsize=(14,5))
plt.bar(np.arange(df.shape[1]), df.isnull().sum()/df.shape[0])
plt.xticks(range(0, len(df.columns.values)), df.columns.values)
plt.xticks(rotation=90)
plt.xlabel('Features')
plt.ylabel('% NaN values')
plt.gca().yaxis.grid(True)
plt.title('Fraction of NaN values in Features')
plt.show()
# Out:
# OR_CASE_ID                              0.000000
# PAT_ID                                  0.000000
# ADMSN_SURGERY_NUMBER                    0.000000
# ADMSN_SURGERY_NUMBER_W_ANES             0.000000
# ANES_CASE_YN                            0.000000
# GENDER                                  0.000000
# ASA_STATUS                              0.000000
# PAT_CLASS                               0.000000
# CASE_START                              0.000219
# CASE_END                                0.000122
# DURATION_MINUTE                         0.000255
# LOCATION_GROUP                          0.000000
# PAPER_CHART_YN                          0.000000
# WEIGHT_KG                               0.007770
# HEIGHT_IN                               0.016173
# BMI                                     0.012427
# LAST_EF                                 0.614711
# LAST_EF_RESULT_DATE                     0.614748
# ADULT_MDRD_GFR_BLK                      0.176843
# ADULT_MDRD_GFR_WHT                      0.176843
# PREOP_CR_TIME                           0.177037
# CVC                                     0.000000
# MIN_GLUCOSE                             0.780208
# MAX_GLUCOSE                             0.780208
# NITRIC_OXIDE                            0.000000
# TOT_RBC                                 0.000000
# CRYSTALLOID_ML                          0.210951
# COLLOID_ML                              0.832338
# PAT_CLASS.1                             0.000000
# CASE_SRV_NAME                           0.002189
# CASE_SRV_NAME_GROUP                     0.002189
# DATE_OF_SERVICE                         0.000000
# HRS_ADMSN_TO_SURGERY                    0.000219
# PRE_SURG_LOCATION                       0.022763
# LAB_CASE                                0.000000
# BICARBONATE                             0.921726
# BICARBONATE HRS_2_SURGERY               0.921678
# CHLORIDE                                0.268735
# CHLORIDE HRS_2_SURGERY                  0.268699
# CREATININE                              0.344845
# CREATININE HRS_2_SURGERY                0.344675
# GLUCOSE                                 0.299075
# GLUCOSE HRS_2_SURGERY                   0.298053
# HEMOGLOBIN                              0.297944
# HEMOGLOBIN HRS_2_SURGERY                0.297859
# INR                                     0.524034
# INR HRS_2_SURGERY                       0.523694
# PLATELET COUNT                          0.388159
# PLATELET COUNT HRS_2_SURGERY            0.388146
# PROTHROMBIN TIME                        0.450928
# PROTHROMBIN TIME HRS_2_SURGERY          0.450381
# POTASSIUM                               0.256576
# POTASSIUM HRS_2_SURGERY                 0.256466
# SODIUM                                  0.282063
# SODIUM HRS_2_SURGERY                    0.282051
# UREA NITROGEN                           0.286757
# UREA NITROGEN HRS_2_SURGERY             0.286246
# WHITE BLOOD CELL COUNT                  0.394251
# WHITE BLOOD CELL COUNT HRS_2_SURGERY    0.394214
# ALBUMIN                                 0.392208
# ALBUMIN HRS_2_SURGERY                   0.392111
# ALKALINE PHOSPHATASE                    0.389362
# ALKALINE PHOSPHATASE HRS_2_SURGERY      0.389326
# ALT                                     0.376813
# ALT HRS_2_SURGERY                       0.373226
# AST                                     0.381775
# AST HRS_2_SURGERY                       0.381665
# BNP                                     0.911597
# BNP HRS_2_SURGERY                       0.907013
# BILIRUBIN TOTAL                         0.444897
# BILIRUBIN TOTAL HRS_2_SURGERY           0.434549
# PRESS_CASE                              0.186230
# SYS BLOOD PRESSURE                      0.186315
# DIAS BLOOD PRESSURE                     0.186315
# BLOOD PRESSURE HRS_2_SURGERY            0.186315
# SYS PAP                                 0.952199
# DIAS PAP                                0.952199
# PAP HRS_2_SURGERY                       0.952199
# PULSE_CASE                              0.130428
# PULSE                                   0.130428
# PULSE HRS_2_SURGERY                     0.130428
# PRN                                     0.130428
# SPO_CASE                                0.038900
# SPO2                                    0.038900
# SPO2 HRS_2_SURGERY                      0.038900
# SRN                                     0.038900
# ECHO_CASE                               0.998699
# ECHO EF                                 0.998699
# ECHO EF HRS_2_SURGERY                   0.998699
# ERN                                     0.998699
# _merge                                  0.000000
# ADMSN_ID                                0.000000
# HCUP_CODE                               0.061189
# HCUP_DESC                               0.061189
# PRIMARY_CPT                             0.059037
# CPT_DESC                                0.072571
# AKIN_STAGE1_YN                          0.000000
# MIN_ADMSN_DAY_AKIN_STAGE1               0.841337
# AKIN_STAGE2_YN                          0.000000
# MIN_ADMSN_DAY_AKIN_STAGE2               0.959434
# AKIN_STAGE3_YN                          0.000000
# MIN_ADMSN_DAY_AKIN_STAGE3               0.944927
# MAX_AKIN_STAGE                          0.000000
# POSTOP_REINTUBATION_YN                  0.000000
# MIN_HRS_TO_POSTOP_REINTUBATION          0.948965
# ADMSN_TRACH_YN                          0.948952
# FLOOR_2_ICU_YN                          0.000000
# INPT_DEATH_YN                           0.000000
# AGE_LT_90                               0.000000
# AKIN_EVENT                              0.000000
# SURGICAL_POSPOM_COMPONENT               0.000000
# POSPOM                                  0.000000
# dtype: float64

# %%
print len(df.HCUP_CODE.unique())
#print df[(df["ASA_STATUS"] == 2) & (df["INPT_DEATH_YN"] == True)].shape
#df.groupby(["INPT_DEATH_YN","ASA_STATUS"]).hist(layout=(5,1),column="HRS_ADMSN_TO_SURGERY", bins=range(0,100,5))
print df.shape
#df = df[df['HRS_ADMSN_TO_SURGERY'] <= 5.]
print df.shape
# plt.xlim(2000,4000)
# Out:
# 188
# (82237, 112)
# (82237, 112)

# %% [markdown]
# # Filter out surgeries that don't occur in RR or SM operating rooms

# %%
print(df.LOCATION_GROUP.unique())
#df = df[df['LOCATION_GROUP'].isin(['RR OR', 'SM OR','SM SC','SM OB OR','RR OB OR'])]
print(df.shape)
df = df[df['LOCATION_GROUP'].isin(['RR OR', 'SM OR', 'SM SC'])]
print(df.shape)
# Out:
# ['RR OFF-SITE' 'SM OR' 'RR OR' 'SM OFF-SITE' 'SM SC' 'SM OB OR' 'RR OB OR']
# (82237, 112)
# (69995, 112)

# %% [markdown]
# ## Filter out surgeries that were not INPATIENT, SAME DAY ADMIT, EMERGENCY, or OVERNIGHT RECOVERY

# %%
# Filter out any surgeries that are not inpatient
#print df['PATIENT_CLASS_INPATIENT']
print "Shape before filtering out outpatient surgeries:", df.shape
#df = df[df['PATIENT_CLASS'].isin(['INPATIENT', 'SAME DAY ADMIT', 'EMERGENCY', 'OVERNIGHT RECOVERY'])]
df = df[df['PAT_CLASS'].isin(['INPATIENT', 'SAME DAY ADMIT', 'EMERGENCY', 'OVERNIGHT RECOVERY'])]
print "Shape after filtering out outpatient surgeries:", df.shape
# Out:
# Shape before filtering out outpatient surgeries: (69995, 112)
# Shape after filtering out outpatient surgeries: (69993, 112)

# %% [markdown]
# ## Filter based on ASA_STATUS, AGE

# %%
try:
    print "Shape before filtering out based on ASA_STATUS:", df.shape
    print "ASA_STATUS mean:", df.ASA_STATUS.mean()
    df = df[(df["ASA_STATUS"] <= MAX_ASA_STATUS) & (df["ASA_STATUS"] >= MIN_ASA_STATUS)]
    print "Shape after filtering out based on ASA_STATUS:", df.shape
    print "ASA_STATUS mean:", df.ASA_STATUS.mean()
except AttributeError:
    pass
print "==================================="
print "Mean age:", df.AGE_LT_90.mean()
print "STD age:", df.AGE_LT_90.std()
df = df[(df["AGE_LT_90"] <= MAX_AGE) & (df["AGE_LT_90"] >= MIN_AGE)]
print "Mean age:", df.AGE_LT_90.mean()
print "STD age:", df.AGE_LT_90.std()
print "Shape after filtering out based on AGE_LT_90:", df.shape
# Out:
# Shape before filtering out based on ASA_STATUS: (69993, 112)
# ASA_STATUS mean: 2.6403068878316405
# Shape after filtering out based on ASA_STATUS: (69993, 112)
# ASA_STATUS mean: 2.6403068878316405
# ===================================
# Mean age: 55.86982984012687
# STD age: 16.956785948990262
# Mean age: 55.86982984012687
# STD age: 16.956785948990262
# Shape after filtering out based on AGE_LT_90: (69993, 112)

# %% [markdown]
# ## Check demographic distributions

# %%
# df.drop_duplicates(inplace=True)
# df.sort_values(by=["ADMSN_ID", "HRS_ADMSN_TO_SURGERY"], inplace=True)
# df.drop_duplicates(subset="ADMSN_ID", keep="first", inplace=True)

print "Number of Patients:", df.shape[0]
print "Patients with in-hospital mortality: {} ({}%)".format(df[TARGET_VARIABLE].value_counts()[1], df[TARGET_VARIABLE].value_counts(normalize="True")[1]*100)
print "Patients with kidney failure: {} ({}%)".format(df.AKIN_EVENT.value_counts()[1], df.AKIN_EVENT.value_counts(normalize="True")[1]*100)
print "Mean age:", df.AGE_LT_90.mean(), " std:", df.AGE_LT_90.std()
print "Number of female patients: {} ({}%)".format(df[df["GENDER"] == "F"].shape[0], df[df["GENDER"] == "F"].shape[0]/float(df.shape[0])*100)

try:
    print "Number of patients in RR OR: {} ({}%)".format(df.LOCATION_GROUP.value_counts()["RR OR"], df.LOCATION_GROUP.value_counts(normalize="True")["RR OR"]*100)
    print "Number of patients in SM OR: {} ({}%)".format(df.LOCATION_GROUP.value_counts()["SM OR"], df.LOCATION_GROUP.value_counts(normalize="True")["SM OR"]*100)
    print "Number of patients in SM SC: {} ({}%)".format(df.LOCATION_GROUP.value_counts()["SM SC"], df.LOCATION_GROUP.value_counts(normalize="True")["SM SC"]*100)
except AttributeError:
    pass
print("="*40)
try:
    print "ASA Status:", df.ASA_STATUS.value_counts()
    print "ASA Status (%):", (df.ASA_STATUS.value_counts()/df.shape[0])*100
except AttributeError:
    pass

print("="*40)
print "Mean age of mortalities:", df[df[TARGET_VARIABLE] == 1].AGE_LT_90.mean(), " std:", df[df[TARGET_VARIABLE] == 1].AGE_LT_90.std()
print("Number of female mortalities: {} ({}%)".format(df[df["GENDER"] == "F"][TARGET_VARIABLE].sum(), 
                                                     df[df["GENDER"] == "F"][TARGET_VARIABLE].sum()/float(df[TARGET_VARIABLE].sum())*100))
print("Number of male mortalities: {} ({}%)".format(df[df["GENDER"] == "M"][TARGET_VARIABLE].sum(), 
                                                     df[df["GENDER"] == "M"][TARGET_VARIABLE].sum()/float(df[TARGET_VARIABLE].sum())*100))
try:
    print("="*40)
    print("Number of mortalities stratified by location")
    print(df.groupby("LOCATION_GROUP")[TARGET_VARIABLE].sum())                                
    print(df.groupby("LOCATION_GROUP")[TARGET_VARIABLE].sum()/float(df[TARGET_VARIABLE].sum())*100)
except AttributeError:
    pass
print("="*40)
print("Number of mortalities stratified by ASA status")
print(df.groupby("ASA_STATUS")[TARGET_VARIABLE].sum())
print(df.groupby("ASA_STATUS")[TARGET_VARIABLE].sum()/float(df[TARGET_VARIABLE].sum())*100)

if verbose:
    print(df["CASE_SRV_NAME"].value_counts())
    print(df["CASE_SRV_NAME"].value_counts()/df.shape[0])*100
    print("="*40)
    print(df[df[TARGET_VARIABLE] == 1]["CASE_SRV_NAME"].value_counts())
    print(df[df[TARGET_VARIABLE] == 1]["CASE_SRV_NAME"].value_counts()/df[TARGET_VARIABLE].sum())*100
# display(df.describe(include="all"))
# Out:
# Number of Patients: 69993
# Patients with in-hospital mortality: 1375 (1.9644821625%)
# Patients with kidney failure: 4918 (7.02641692741%)
# Mean age: 55.86982984012687  std: 16.956785948990262
# Number of female patients: 35471 (50.6779249354%)
# Number of patients in RR OR: 46073 (65.825153944%)
# Number of patients in SM OR: 22355 (31.9389081765%)
# Number of patients in SM SC: 1565 (2.2359378795%)
# ========================================
# ASA Status: 3.0    32666
# 2.0    24960
# 4.0     7534
# 1.0     4354
# 5.0      479
# Name: ASA_STATUS, dtype: int64
# ASA Status (%): 3.0    46.670381
# 2.0    35.660709
# 4.0    10.763934
# 1.0     6.220622
# 5.0     0.684354
# Name: ASA_STATUS, dtype: float64
# ========================================
# Mean age of mortalities: 58.49454545454545  std: 15.634696911640363
# Number of female mortalities: 534 (38.8363636364%)
# Number of male mortalities: 841 (61.1636363636%)
# ========================================
# Number of mortalities stratified by location
# LOCATION_GROUP
# RR OR    1168.0
# SM OR     207.0
# SM SC       0.0
# Name: INPT_DEATH_YN, dtype: float64
# LOCATION_GROUP
# RR OR    84.945455
# SM OR    15.054545
# SM SC     0.000000
# Name: INPT_DEATH_YN, dtype: float64
# ========================================
# Number of mortalities stratified by ASA status
# ASA_STATUS
# 1.0      3.0
# 2.0     17.0
# 3.0    334.0
# 4.0    844.0
# 5.0    177.0
# Name: INPT_DEATH_YN, dtype: float64
# ASA_STATUS
# 1.0     0.218182
# 2.0     1.236364
# 3.0    24.290909
# 4.0    61.381818
# 5.0    12.872727
# Name: INPT_DEATH_YN, dtype: float64

# %%
df[df['CASE_SRV_NAME'] == "Pediatrics, Hematology and Oncology"]["AGE_LT_90"].hist()

# %%
g = df.groupby("CASE_SRV_NAME")
kv = {}
for n, grp in g:
    kv[n] = grp[TARGET_VARIABLE].sum()
import operator
sorted_x = sorted(kv.items(), key=operator.itemgetter(1), reverse=True)
# for i in sorted_x:
#     print("{}:\t{}".format(i[0], i[1]))
pd.DataFrame(sorted_x, columns=["CASE_SRV_NAME", "INPT_DEATH_COUNT"])
# Out:
#                                       CASE_SRV_NAME  INPT_DEATH_COUNT
# 0                                  Surgery, Cardiac               291
# 1                               Surgery, Transplant               251
# 2                                  Surgery, General               178
# 3                              Neurological Surgery               152
# 4                                  Surgery, Surgery               118
# 5                                 Surgery, Vascular                73
# 6                                 Surgery, Thoracic                49
# 7                        Medicine, Gastroenterology                49
# 8                                    Otolaryngology                48
# 9                                      Orthopaedics                45
# 10                                          Urology                44
# 11                      Medicine, Pulmonary Disease                23
# 12                        Obstetrics and Gynecology                13
# 13                                        Radiology                 9
# 14                             Medicine, Cardiology                 8
# 15                                Surgery, Oncology                 7
# 16                                    Ophthalmology                 5
# 17                                 Surgery, Plastic                 4
# 18                               Dentistry-Hospital                 3
# 19                                   Anesthesiology                 1
# 20                Medicine, Hematology and Oncology                 1
# 21                                         Podiatry                 1
# 22              Pediatrics, Hematology and Oncology                 1
# 23                 Medicine, Critical Care Medicine                 1
# 24                               Radiation Oncology                 0
# 25  Pediatrics, Cardiology / Cardiovascular Disease                 0
# 26             Physical Medicine and Rehabilitation                 0
# 27                      Medicine, Internal Medicine                 0
# 28                                        Neurology                 0
# 29                  Surgery, Oral and Maxillofacial                 0
# 30                              Pediatrics, Urology                 0
# 31                     Pediatrics, Gastroenterology                 0
# 32                              Surgery, Pediatrics                 0

# %%
# df.boxplot(column="PRED_ASA_STATUS", by="ASA_STATUS")
# plt.title("")
# plt.suptitle("")
# plt.ylabel("PRED_ASA_STATUS")

# %%
# look at distribution of HCUP codes in dataset and in patients that die
print "HCUP Codes:", 
hcup_df = pd.DataFrame([df.HCUP_DESC.value_counts(), (df.HCUP_DESC.value_counts()/df.shape[0])*100]).transpose()
hcup_df.columns = ["HCUP_CODE_COUNT", "HCUP_CODE_PERCENT"]
hcup_df.HCUP_CODE_COUNT = hcup_df.HCUP_CODE_COUNT.astype('int32')
hcup_df.HCUP_CODE_PERCENT = hcup_df.HCUP_CODE_PERCENT.round(1)
#display(hcup_df)
hcup_df.to_csv(os.path.join(dir_to_save_files, "HCUP_codes_full_dataset.txt"), sep="\t", header=True, index=True)
hcup_inptdeath_df = pd.DataFrame([df[df[TARGET_VARIABLE] == True].HCUP_DESC.value_counts(), (df[df[TARGET_VARIABLE] == True].HCUP_DESC.value_counts()/df[df[TARGET_VARIABLE] == True].shape[0])*100]).transpose()
hcup_inptdeath_df.columns = ["HCUP_CODE_COUNT", "HCUP_CODE_PERCENT"]
hcup_inptdeath_df.HCUP_CODE_COUNT = hcup_inptdeath_df.HCUP_CODE_COUNT.astype('int32')
hcup_inptdeath_df.HCUP_CODE_PERCENT = hcup_inptdeath_df.HCUP_CODE_PERCENT.round(1)
display(hcup_inptdeath_df)
hcup_inptdeath_df.to_csv(os.path.join(dir_to_save_files, "HCUP_codes_inpt_death.txt"), sep="\t", header=True, index=True)
# Out:
# HCUP Codes:
#                                                     HCUP_CODE_COUNT  \
# OTHER OR PROCEDURES ON VESSELS OTHER THAN HEAD ...              131
# INCISION AND EXCISION OF CNS                                     99
# OTHER OR HEART PROCEDURES                                        73
# OTHER ORGAN TRANSPLANTATION                                      66
# EXPLORATORY LAPAROTOMY                                           60
# TRACHEOSTOMY, TEMPORARY AND PERMANENT                            54
# SMALL BOWEL RESECTION                                            52
# OTHER OR GASTROINTESTINAL THERAPEUTIC PROCEDURES                 49
# HEART VALVE PROCEDURES                                           46
# COLORECTAL RESECTION                                             43
# DEBRIDEMENT OF WOUND, INFECTION OR BURN                          36
# EXTRACORPOREAL CIRCULATION AUXILIARY TO OPEN HE...               31
# OTHER OR THERAPEUTIC PROCEDURES ON RESPIRATORY ...               26
# INSERTION, REPLACEMENT, OR REMOVAL OF EXTRACRAN...               24
# OTHER DIAGNOSTIC PROCEDURES (INTERVIEW, EVALUAT...               23
# ILEOSTOMY AND OTHER ENTEROSTOMY                                  22
# UPPER GASTROINTESTINAL ENDOSCOPY, BIOPSY                         20
# OTHER OR UPPER GI THERAPEUTIC PROCEDURES                         20
# DIAGNOSTIC BRONCHOSCOPY AND BIOPSY OF BRONCHUS                   19
# AMPUTATION OF LOWER EXTREMITY                                    18
# AORTIC RESECTION, REPLACEMENT OR ANASTOMOSIS                     17
# TREATMENT, FRACTURE OR DISLOCATION OF HIP AND F...               17
# CORONARY ARTERY BYPASS GRAFT (CABG)                              14
# OTHER OR THERAPEUTIC PROCEDURES ON BONE                          14
# OTHER OR LOWER GI THERAPEUTIC PROCEDURES                         13
# OTHER VASCULAR CATHETERIZATION, NOT HEART                        12
# EXCISION, LYSIS PERITONEAL ADHESIONS                             11
# TRANSURETHRAL EXCISION, DRAINAGE, OR REMOVAL UR...               11
# OTHER THERAPEUTIC PROCEDURES, HEMIC AND LYMPHAT...               10
# LAPAROSCOPY                                                      10
# DIAGNOSTIC ULTRASOUND OF HEART (ECHOCARDIOGRAM)                  10
# PARTIAL EXCISION BONE                                             9
# GASTROSTOMY, TEMPORARY AND PERMANENT                              9
# OTHER OR THERAPEUTIC NERVOUS SYSTEM PROCEDURES                    9
# SKIN GRAFT                                                        8
# SUTURE OF SKIN AND SUBCUTANEOUS TISSUE                            8
# SPINAL FUSION                                                     7
# INCISION AND DRAINAGE, SKIN AND SUBCUTANEOUS TI...                7
# ENDOSCOPIC RETROGRADE CANNULATION OF PANCREAS (...                7
# TRACTION, SPLINTS, AND OTHER WOUND CARE                           6
# OTHER HERNIA REPAIR                                               6
# OTHER OR PROCEDURES ON VESSELS OF HEAD AND NECK                   6
# LOBECTOMY OR PNEUMONECTOMY                                        6
# HYSTERECTOMY, ABDOMINAL AND VAGINAL                               6
# ABDOMINAL PARACENTESIS                                            5
# COLOSTOMY, TEMPORARY AND PERMANENT                                5
# OTHER OR THERAPEUTIC PROCEDURES ON JOINTS                         5
# KIDNEY TRANSPLANT                                                 5
# EMBOLECTOMY AND ENDARTERECTOMY OF LOWER LIMBS                     5
# COLONOSCOPY AND BIOPSY                                            5
# OTHER OR THERAPEUTIC PROCEDURES OF URINARY TRACT                  4
# INSERTION, REVISION, REPLACEMENT, REMOVAL OF CA...                4
# OTHER OR THERAPEUTIC PROCEDURES ON NOSE, MOUTH ...                4
# OTHER DIAGNOSTIC PROCEDURES, FEMALE ORGANS                        4
# OTHER THERAPEUTIC ENDOCRINE PROCEDURES                            4
# CREATION, REVISION AND REMOVAL OF ARTERIOVENOUS...                4
# CHOLECYSTECTOMY AND COMMON DUCT EXPLORATION                       4
# INCISION OF PLEURA, THORACENTESIS, CHEST DRAINAGE                 4
# PROCTOSCOPY AND ANORECTAL BIOPSY                                  4
# OTHER VASCULAR BYPASS AND SHUNT, NOT HEART                        4
# NEPHRECTOMY, PARTIAL OR COMPLETE                                  3
# INGUINAL AND FEMORAL HERNIA REPAIR                                3
# OTHER OR THERAPEUTIC PROCEDURES ON MUSCULOSKELE...                3
# OTHER DIAGNOSTIC PROCEDURES ON LUNG AND BRONCHUS                  3
# TRACHEOSCOPY AND LARYNGOSCOPY WITH BIOPSY                         3
# BIOPSY OF LIVER                                                   3
# OTHER THERAPEUTIC PROCEDURES ON MUSCLES AND TEN...                3
# OPEN PROSTATECTOMY                                                3
# LAMINECTOMY, EXCISION INTERVERTEBRAL DISC                         2
# OTHER DIAGNOSTIC ULTRASOUND                                       2
# OTHER OR THERAPEUTIC PROCEDURES, MALE GENITAL                     2
# ARTHROSCOPY                                                       2
# DIAGNOSTIC PROCEDURES ON NOSE, MOUTH AND PHARYNX                  2
# PERIPHERAL VASCULAR BYPASS                                        2
# HIP REPLACEMENT, TOTAL AND PARTIAL                                2
# PROCEDURES ON SPLEEN                                              2
# OTHER DIAGNOSTIC PROCEDURES ON MUSCULOSKELETAL ...                2
# CONTROL OF EPISTAXIS                                              1
# OTHER FRACTURE AND DISLOCATION PROCEDURE                          1
# NEPHROTOMY AND NEPHROSTOMY                                        1
# DIAGNOSTIC DILATATION AND CURETTAGE (D&C)                         1
# EXTRACORPOREAL LITHOTRIPSY, URINARY                               1
# OTHER NON-OR UPPER GI THERAPEUTIC PROCEDURES                      1
# GASTRECTOMY, PARTIAL AND TOTAL                                    1
# PERCUTANEOUS TRANSLUMINAL CORONARY ANGIOPLASTY ...                1
# OTHER THERAPEUTIC PROCEDURES ON EYELIDS, CONJUN...                1
# REPAIR OF CYSTOCELE AND RECTOCELE, OBLITERATION...                1
# TREATMENT, FRACTURE OR DISLOCATION OF LOWER EXT...                1
# ENDOSCOPY AND ENDOSCOPIC BIOPSY OF THE URINARY ...                1
# OTHER DIAGNOSTIC PROCEDURES OF RESPIRATORY TRAC...                1
# DECOMPRESSION PERIPHERAL NERVE                                    1
# PLASTIC PROCEDURES ON NOSE                                        1
# MASTOIDECTOMY                                                     1
# MYRINGOTOMY                                                       1
# OTHER NON-OR THERAPEUTIC PROCEDURES ON RESPIRAT...                1
# REPAIR OF RETINAL TEAR, DETACHMENT                                1
# OTHER DIAGNOSTIC NERVOUS SYSTEM PROCEDURES                        1
# ANESTHESIA                                                        1
# EXCISION OF SKIN LESION                                           1
# PROCEDURES ON THE URETHRA                                         1
#
#                                                     HCUP_CODE_PERCENT
# OTHER OR PROCEDURES ON VESSELS OTHER THAN HEAD ...                9.5
# INCISION AND EXCISION OF CNS                                      7.2
# OTHER OR HEART PROCEDURES                                         5.3
# OTHER ORGAN TRANSPLANTATION                                       4.8
# EXPLORATORY LAPAROTOMY                                            4.4
# TRACHEOSTOMY, TEMPORARY AND PERMANENT                             3.9
# SMALL BOWEL RESECTION                                             3.8
# OTHER OR GASTROINTESTINAL THERAPEUTIC PROCEDURES                  3.6
# HEART VALVE PROCEDURES                                            3.3
# COLORECTAL RESECTION                                              3.1
# DEBRIDEMENT OF WOUND, INFECTION OR BURN                           2.6
# EXTRACORPOREAL CIRCULATION AUXILIARY TO OPEN HE...                2.3
# OTHER OR THERAPEUTIC PROCEDURES ON RESPIRATORY ...                1.9
# INSERTION, REPLACEMENT, OR REMOVAL OF EXTRACRAN...                1.7
# OTHER DIAGNOSTIC PROCEDURES (INTERVIEW, EVALUAT...                1.7
# ILEOSTOMY AND OTHER ENTEROSTOMY                                   1.6
# UPPER GASTROINTESTINAL ENDOSCOPY, BIOPSY                          1.5
# OTHER OR UPPER GI THERAPEUTIC PROCEDURES                          1.5
# DIAGNOSTIC BRONCHOSCOPY AND BIOPSY OF BRONCHUS                    1.4
# AMPUTATION OF LOWER EXTREMITY                                     1.3
# AORTIC RESECTION, REPLACEMENT OR ANASTOMOSIS                      1.2
# TREATMENT, FRACTURE OR DISLOCATION OF HIP AND F...                1.2
# CORONARY ARTERY BYPASS GRAFT (CABG)                               1.0
# OTHER OR THERAPEUTIC PROCEDURES ON BONE                           1.0
# OTHER OR LOWER GI THERAPEUTIC PROCEDURES                          0.9
# OTHER VASCULAR CATHETERIZATION, NOT HEART                         0.9
# EXCISION, LYSIS PERITONEAL ADHESIONS                              0.8
# TRANSURETHRAL EXCISION, DRAINAGE, OR REMOVAL UR...                0.8
# OTHER THERAPEUTIC PROCEDURES, HEMIC AND LYMPHAT...                0.7
# LAPAROSCOPY                                                       0.7
# DIAGNOSTIC ULTRASOUND OF HEART (ECHOCARDIOGRAM)                   0.7
# PARTIAL EXCISION BONE                                             0.7
# GASTROSTOMY, TEMPORARY AND PERMANENT                              0.7
# OTHER OR THERAPEUTIC NERVOUS SYSTEM PROCEDURES                    0.7
# SKIN GRAFT                                                        0.6
# SUTURE OF SKIN AND SUBCUTANEOUS TISSUE                            0.6
# SPINAL FUSION                                                     0.5
# INCISION AND DRAINAGE, SKIN AND SUBCUTANEOUS TI...                0.5
# ENDOSCOPIC RETROGRADE CANNULATION OF PANCREAS (...                0.5
# TRACTION, SPLINTS, AND OTHER WOUND CARE                           0.4
# OTHER HERNIA REPAIR                                               0.4
# OTHER OR PROCEDURES ON VESSELS OF HEAD AND NECK                   0.4
# LOBECTOMY OR PNEUMONECTOMY                                        0.4
# HYSTERECTOMY, ABDOMINAL AND VAGINAL                               0.4
# ABDOMINAL PARACENTESIS                                            0.4
# COLOSTOMY, TEMPORARY AND PERMANENT                                0.4
# OTHER OR THERAPEUTIC PROCEDURES ON JOINTS                         0.4
# KIDNEY TRANSPLANT                                                 0.4
# EMBOLECTOMY AND ENDARTERECTOMY OF LOWER LIMBS                     0.4
# COLONOSCOPY AND BIOPSY                                            0.4
# OTHER OR THERAPEUTIC PROCEDURES OF URINARY TRACT                  0.3
# INSERTION, REVISION, REPLACEMENT, REMOVAL OF CA...                0.3
# OTHER OR THERAPEUTIC PROCEDURES ON NOSE, MOUTH ...                0.3
# OTHER DIAGNOSTIC PROCEDURES, FEMALE ORGANS                        0.3
# OTHER THERAPEUTIC ENDOCRINE PROCEDURES                            0.3
# CREATION, REVISION AND REMOVAL OF ARTERIOVENOUS...                0.3
# CHOLECYSTECTOMY AND COMMON DUCT EXPLORATION                       0.3
# INCISION OF PLEURA, THORACENTESIS, CHEST DRAINAGE                 0.3
# PROCTOSCOPY AND ANORECTAL BIOPSY                                  0.3
# OTHER VASCULAR BYPASS AND SHUNT, NOT HEART                        0.3
# NEPHRECTOMY, PARTIAL OR COMPLETE                                  0.2
# INGUINAL AND FEMORAL HERNIA REPAIR                                0.2
# OTHER OR THERAPEUTIC PROCEDURES ON MUSCULOSKELE...                0.2
# OTHER DIAGNOSTIC PROCEDURES ON LUNG AND BRONCHUS                  0.2
# TRACHEOSCOPY AND LARYNGOSCOPY WITH BIOPSY                         0.2
# BIOPSY OF LIVER                                                   0.2
# OTHER THERAPEUTIC PROCEDURES ON MUSCLES AND TEN...                0.2
# OPEN PROSTATECTOMY                                                0.2
# LAMINECTOMY, EXCISION INTERVERTEBRAL DISC                         0.1
# OTHER DIAGNOSTIC ULTRASOUND                                       0.1
# OTHER OR THERAPEUTIC PROCEDURES, MALE GENITAL                     0.1
# ARTHROSCOPY                                                       0.1
# DIAGNOSTIC PROCEDURES ON NOSE, MOUTH AND PHARYNX                  0.1
# PERIPHERAL VASCULAR BYPASS                                        0.1
# HIP REPLACEMENT, TOTAL AND PARTIAL                                0.1
# PROCEDURES ON SPLEEN                                              0.1
# OTHER DIAGNOSTIC PROCEDURES ON MUSCULOSKELETAL ...                0.1
# CONTROL OF EPISTAXIS                                              0.1
# OTHER FRACTURE AND DISLOCATION PROCEDURE                          0.1
# NEPHROTOMY AND NEPHROSTOMY                                        0.1
# DIAGNOSTIC DILATATION AND CURETTAGE (D&C)                         0.1
# EXTRACORPOREAL LITHOTRIPSY, URINARY                               0.1
# OTHER NON-OR UPPER GI THERAPEUTIC PROCEDURES                      0.1
# GASTRECTOMY, PARTIAL AND TOTAL                                    0.1
# PERCUTANEOUS TRANSLUMINAL CORONARY ANGIOPLASTY ...                0.1
# OTHER THERAPEUTIC PROCEDURES ON EYELIDS, CONJUN...                0.1
# REPAIR OF CYSTOCELE AND RECTOCELE, OBLITERATION...                0.1
# TREATMENT, FRACTURE OR DISLOCATION OF LOWER EXT...                0.1
# ENDOSCOPY AND ENDOSCOPIC BIOPSY OF THE URINARY ...                0.1
# OTHER DIAGNOSTIC PROCEDURES OF RESPIRATORY TRAC...                0.1
# DECOMPRESSION PERIPHERAL NERVE                                    0.1
# PLASTIC PROCEDURES ON NOSE                                        0.1
# MASTOIDECTOMY                                                     0.1
# MYRINGOTOMY                                                       0.1
# OTHER NON-OR THERAPEUTIC PROCEDURES ON RESPIRAT...                0.1
# REPAIR OF RETINAL TEAR, DETACHMENT                                0.1
# OTHER DIAGNOSTIC NERVOUS SYSTEM PROCEDURES                        0.1
# ANESTHESIA                                                        0.1
# EXCISION OF SKIN LESION                                           0.1
# PROCEDURES ON THE URETHRA                                         0.1

# %% [markdown]
# ## Remove outlier values
# Outliers are values greater than 3 standard deviations from the mean. We only remove outliers for continuous variables (not categorical).

# %%
string_cols = ['PRE_SURG_LOCATION', 'CASE_SRV_NAME_GROUP', 'CASE_SRV_NAME', 
               'PRIMARY_CPT', 'GENDER', 'HCUP_DESC', 'CPT_DESC', 'PAT_CLASS', 
               'OR_CASE_ID', 'ADMSN_ID']
dff = df.drop(['PRE_SURG_LOCATION', 'CASE_SRV_NAME_GROUP', 'CASE_SRV_NAME', 'PRIMARY_CPT',
                                  'GENDER', 'HCUP_DESC', 'CPT_DESC', 'PAT_CLASS', 'OR_CASE_ID', 'ADMSN_ID'], axis=1)
dff = df.select_dtypes(include=['float64'])
df_string_cols = df[df.columns.difference(dff.columns.values)]
print df_string_cols.columns.values
#display(dff.describe())
print (np.abs(st.zscore(dff, axis=1)) > 3)
#print dff.sub(dff.mean()).div(dff.std()).abs().lt(3)
df_no_outliers = dff[dff.sub(dff.mean()).div(dff.std()).abs().lt(4)]
df_no_outliers[df_string_cols.columns.values] = df_string_cols
if verbose:
    display(df_no_outliers.describe(include="all"))
df = df_no_outliers
# Out:
# ['AKIN_EVENT' 'AKIN_STAGE1_YN' 'AKIN_STAGE2_YN' 'AKIN_STAGE3_YN'
#  'ANES_CASE_YN' 'CASE_SRV_NAME' 'CASE_SRV_NAME_GROUP' 'CPT_DESC' 'CVC'
#  'DATE_OF_SERVICE' 'FLOOR_2_ICU_YN' 'GENDER' 'HCUP_DESC' 'INPT_DEATH_YN'
#  'LAST_EF' 'LOCATION_GROUP' 'MAX_AKIN_STAGE' 'NITRIC_OXIDE' 'OR_CASE_ID'
#  'PAPER_CHART_YN' 'PAT_CLASS' 'PAT_CLASS.1' 'PAT_ID'
#  'POSTOP_REINTUBATION_YN' 'PRE_SURG_LOCATION' 'PRIMARY_CPT'
#  'SURGICAL_POSPOM_COMPONENT' 'TOT_RBC' '_merge']
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]

# %% [markdown]
# # Remove variables related to lab times (i.e. *.HRS_2_SURGERY)
# If you want to include these variables in the model, comment this block of code

# %%
# remove variables that have to do with time
cols_to_keep_no_hrs2surgery = [c for c in df.columns if not c.endswith("HRS_2_SURGERY")]
print cols_to_keep_no_hrs2surgery
print len(cols_to_keep_no_hrs2surgery)
df=df[cols_to_keep_no_hrs2surgery]
# Out:
# ['ADMSN_SURGERY_NUMBER', 'ADMSN_SURGERY_NUMBER_W_ANES', 'ASA_STATUS', 'CASE_START', 'CASE_END', 'DURATION_MINUTE', 'WEIGHT_KG', 'HEIGHT_IN', 'BMI', 'LAST_EF_RESULT_DATE', 'ADULT_MDRD_GFR_BLK', 'ADULT_MDRD_GFR_WHT', 'PREOP_CR_TIME', 'MIN_GLUCOSE', 'MAX_GLUCOSE', 'CRYSTALLOID_ML', 'COLLOID_ML', 'HRS_ADMSN_TO_SURGERY', 'LAB_CASE', 'BICARBONATE', 'CHLORIDE', 'CREATININE', 'GLUCOSE', 'HEMOGLOBIN', 'INR', 'PLATELET COUNT', 'PROTHROMBIN TIME', 'POTASSIUM', 'SODIUM', 'UREA NITROGEN', 'WHITE BLOOD CELL COUNT', 'ALBUMIN', 'ALKALINE PHOSPHATASE', 'ALT', 'AST', 'BNP', 'BILIRUBIN TOTAL', 'PRESS_CASE', 'SYS BLOOD PRESSURE', 'DIAS BLOOD PRESSURE', 'SYS PAP', 'DIAS PAP', 'PULSE_CASE', 'PULSE', 'PRN', 'SPO_CASE', 'SPO2', 'SRN', 'ECHO_CASE', 'ECHO EF', 'ERN', 'ADMSN_ID', 'HCUP_CODE', 'MIN_ADMSN_DAY_AKIN_STAGE1', 'MIN_ADMSN_DAY_AKIN_STAGE2', 'MIN_ADMSN_DAY_AKIN_STAGE3', 'MIN_HRS_TO_POSTOP_REINTUBATION', 'ADMSN_TRACH_YN', 'AGE_LT_90', 'POSPOM', 'AKIN_EVENT', 'AKIN_STAGE1_YN', 'AKIN_STAGE2_YN', 'AKIN_STAGE3_YN', 'ANES_CASE_YN', 'CASE_SRV_NAME', 'CASE_SRV_NAME_GROUP', 'CPT_DESC', 'CVC', 'DATE_OF_SERVICE', 'FLOOR_2_ICU_YN', 'GENDER', 'HCUP_DESC', 'INPT_DEATH_YN', 'LAST_EF', 'LOCATION_GROUP', 'MAX_AKIN_STAGE', 'NITRIC_OXIDE', 'OR_CASE_ID', 'PAPER_CHART_YN', 'PAT_CLASS', 'PAT_CLASS.1', 'PAT_ID', 'POSTOP_REINTUBATION_YN', 'PRE_SURG_LOCATION', 'PRIMARY_CPT', 'SURGICAL_POSPOM_COMPONENT', 'TOT_RBC', '_merge']
# 89

# %% [markdown]
# # Remove unnecessary features
# These features are either not needed (ex. descriptions of surgery codes) or not wanted

# %%
# save this for checking predictions over time
admsn_surgery_number = df["ADMSN_SURGERY_NUMBER"]
print admsn_surgery_number.shape
or_case_id_number = df["OR_CASE_ID"]
admsn_ids = df['ADMSN_ID']
# Out:
# (69993,)

# %%
# cat_to_drop = ['OR_CASE_ID', 'HCUP_DESC', 'CPT_DESC', 'ECHO_CASE',
#                    'CASE_SRV_NAME', 'CASE_SRV_NAME_GROUP', 'PRIMARY_CPT']
df = df[final_features + [TARGET_VARIABLE]]
#print(df.drop(outcome_vars + cat_to_drop, axis=1).shape[1])
pd.DataFrame(df[final_features].isnull().sum()/df.shape[0]).apply(lambda x: np.round(x, 3)).to_csv(os.path.join(dir_to_save_files, "Feature_List_with_null.txt"), sep="|", header=False, index=True)

# %%
df[TARGET_VARIABLE].mean()
# Out:
# 0.019644821625019643

# %% [markdown]
# ## Plot feature correlation

# %%
import seaborn as sns

sns.set(style="white")

# Generate a mask for the upper triangle
mask = np.zeros_like(df.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(16, 13))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(df.corr(), mask=mask, cmap=cmap, vmax=1.0, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## One-hot encode categorical variables

# %%
# one-hot encode values in categorical columns (creates 1 column per possible state)
## removed: 'NITRIC_OXIDE', 'ART_LINE', 'CVC', 'PA_CATHETER',
#categorical_string_cols = ['PAT_CLASS', 'HCUP_CODE', 'GENDER', 'CASE_SRV_NAME', 'PRE_SURG_LOCATION']
#categorical_string_cols = []
# for i in categorical_string_cols:
#     df[i] = pd.Categorical(df[i]).codes
# removed

# %%
#dummy_cols = ['PAT_CLASS', 'HCUP_CODE', 'GENDER', 'CASE_SRV_NAME', 'PRE_SURG_LOCATION']
#dummy_cols = ['GENDER']
for var in cat_vars:
    try:
        # drop_first uses k-1 dummies out of k categories
        print var
        df = pd.get_dummies(df, columns=[var], drop_first=True)
        pass
    except ValueError:
        pass
    except KeyError:
        pass
# remove categorical variables (string values)
for var in cat_vars:
    try:
        df.drop(var, axis=1, inplace=True)
        pass
    except ValueError:
        print var, 'already dropped'
    except KeyError: 
        print var, 'already dropped'
# Out:
# PAT_CLASS
# HCUP_CODE
# GENDER
# CASE_SRV_NAME
# PRE_SURG_LOCATION
# PAT_CLASS already dropped
# HCUP_CODE already dropped
# GENDER already dropped
# CASE_SRV_NAME already dropped
# PRE_SURG_LOCATION already dropped

# %% [markdown]
# ## Remove features we don't want to include

# %%
if len(feature_whitelist) == 0:
    # drop categorical variables that have too many unique values
#     cat_to_drop = ['ETOH_USE', 'SMOKING_STATUS', 'HCUP_DESC', 'CPT_DESC', 'ADMSN_SURGERY_NUMBER_W_ANES', 
#                 'ADMSN_SURGERY_NUMBER', 'PREOP_EF_RESULT', 'PREOP_EF_RESULT_DATE', 'PRIMARY_CPT',
#                  'PAT_ID', 'PAT_ADMSN_NUMBER', 'ANES_CASE_YN', 'PAPER_CHART_YN', 'PATIENT_CLASS',
#                   'COLLOID_ML', 'NITRIC_OXIDE', 'ART_LINE', 'CVC', 'PA_CATHETER', 'CRYSTALLOID_ML', 
#                    'TOT_RBC', 'HEIGHT', 'WEIGHT', 'BMI', 'DURATION_MINUTE', 'ETOH_USE_AMOUNT',
#                   'ANESTHESIOLOGIST_ID', 'SURGEON_ID']
#     cat_to_drop = ['ETOH_USE', 'SMOKING_STATUS', 'HCUP_DESC', 'CPT_DESC', 'ADMSN_SURGERY_NUMBER_W_ANES', 
#                  'ADMSN_SURGERY_NUMBER', 'PREOP_EF_RESULT', 'PREOP_EF_RESULT_DATE', 'PRIMARY_CPT',
#                   'PAT_ID', 'PAT_ADMSN_NUMBER', 'ANES_CASE_YN', 'PAPER_CHART_YN', 'PATIENT_CLASS',
#                   'ANESTHESIOLOGIST_ID', 'SURGEON_ID']
    #cat_to_drop = ['OR_CASE_ID','PAT_CLASS','PRIMARY_CPT','CPT_DESC','HCUP_CODE','HCUP_DESC','CASE_SRV_NAME','CASE_SRV_NAME_GROUP','HRS_ADMSN_TO_SURGERY','PRE_SURG_LOCATION']
#     cat_to_drop = ['OR_CASE_ID', 'HCUP_DESC', 'CPT_DESC', 'ECHO_CASE',
#                    'CASE_SRV_NAME', 'CASE_SRV_NAME_GROUP', 'PRIMARY_CPT']
    for cat in cat_to_drop:
        try:
            df.drop(cat, axis=1, inplace=True)
        except ValueError:
            print cat, 'already dropped'
        except KeyError:
            print cat, 'already dropped'
#print df.columns.values
for col in sorted(df.columns.values):
    print col, "\t\t", df[col].dtype
# Out:
# ETOH_USE already dropped
# SMOKING_STATUS already dropped
# HCUP_DESC already dropped
# CPT_DESC already dropped
# ADMSN_SURGERY_NUMBER_W_ANES already dropped
# ADMSN_SURGERY_NUMBER already dropped
# PREOP_EF_RESULT already dropped
# PREOP_EF_RESULT_DATE already dropped
# PRIMARY_CPT already dropped
# PAT_ID already dropped
# PAT_ADMSN_NUMBER already dropped
# ANES_CASE_YN already dropped
# PAPER_CHART_YN already dropped
# PATIENT_CLASS already dropped
# ANESTHESIOLOGIST_ID already dropped
# SURGEON_ID already dropped
# OR_CASE_ID already dropped
# HCUP_DESC already dropped
# CPT_DESC already dropped
# CASE_SRV_NAME already dropped
# CASE_SRV_NAME_GROUP already dropped
# PRIMARY_CPT already dropped
# INPT_DEATH_YN 		bool
# POSPOM 		float64

# %% [markdown]
# ## Remove target variables from data frame

# %%
print "Column names:", df.columns.values
try:
    print(df.shape)
    y = np.ravel(df[TARGET_VARIABLE])
    print(y.mean())
    #asa_status = df["ASA_STATUS"]
    input_death_yn = df[TARGET_VARIABLE]
    df.drop(TARGET_VARIABLE, axis=1, inplace=True, errors='ignore')
    df.drop(outcome_vars, axis=1, inplace=True, errors='ignore')
except KeyError:
    print TARGET_VARIABLE, "already dropped"
# http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.Imputer.html
# default stragegy: mean
# if len(feature_whitelist) > 0:
#     feature_whitelist = [c for c in feature_whitelist if not c.endswith(".HRS_2_SURGERY")]
#     df = df[feature_whitelist]
print df.isnull().sum()
# Out:
# Column names: ['POSPOM' 'INPT_DEATH_YN']
# (69993, 2)
# 0.019644821625019643
# POSPOM    3
# dtype: int64

# %% [markdown]
# ## Impute missing data
#
# Note that if running with only a single feature (i.e. only ASA status) that you will have to change
# df.iloc[:,0:] to df.iloc[:,1:] since the first column will be the ID and we don't want that

# %%
# This uses mean-value imputation
# imputer = Imputer()
# transformed_X = imputer.fit_transform(df.iloc[:,1:])

# %%
# print df.shape
# [transformed_X, mu_hat, U, s, Vt] = emsvd(df.iloc[:,1:], k=8, tol=1E-3)
#print mu_hat
#df.drop(["ASA_STATUS"], inplace=True)

# try: 
#     imputer = Imputer(strategy="median")
#     #transformed_X = imputer.fit_transform(df.iloc[:,1:])
#     transformed_X = SoftImpute(max_iters=200).complete(df.iloc[:,0:])
#     #transformed_X = MICE().complete(df.iloc[:,1:])
#     #transformed_X = df.iloc[:,1:]
# except ValueError as e:
#     print "ERROR:", e
#     transformed_X = np.array(df.iloc[:,0:])

# %%
#pd.DataFrame(data=transformed_X, columns=df.columns.values[0:]).describe(include="all")

# %%
# flatten y into 1D array
print len(y)
print "Mean of target vector:", y.mean()
#tdf = pd.DataFrame(data=transformed_X)
#tdf.describe()
# Out:
# 69993
# Mean of target vector: 0.019644821625019643

# %%
print(y.sum())
# Out:
# 1375

# %%
print(or_case_id_number.shape)
print(y.shape)
X_train = df[or_case_id_number.isin(test_or_case_ids.iloc[:,0])]
y_train = y[or_case_id_number.isin(test_or_case_ids.iloc[:,0])]

print(X_train.shape)
print(y_train.shape)
X_test = df[~(or_case_id_number.isin(test_or_case_ids.iloc[:,0]))]
y_test = y[~(or_case_id_number.isin(test_or_case_ids.iloc[:,0]))]
print(X_test.shape)
print(y_test.shape)
# Out:
# (69993,)
# (69993,)
# (7542, 1)
# (7542,)
# (62451, 1)
# (62451,)

# %% [markdown]
# ## Split data into training, testing sets

# %%
group_by_admsn = admsn_ids.astype('category').cat.codes
print "number of operations:", len(group_by_admsn)
print "number of unique admission groups:", len(np.unique(group_by_admsn))
group_kfold = GroupKFold(n_splits=5)

# take the first fold of the k-fold split
train_index, test_index = group_kfold.split(np.array(df.iloc[:,0:]), y, group_by_admsn).next()
#train_index, test_index = group_kfold.split(transformed_X, y, group_by_admsn).next()
X_train, X_test = df.iloc[train_index], df.iloc[test_index]
#X_train, X_test = transformed_X[train_index], transformed_X[test_index]
y_train, y_test = y[train_index], y[test_index]

# X_train, X_test, y_train, y_test = train_test_split(transformed_X, y, test_size=0.2, random_state=43)
#X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.33, random_state=42)
print "num X_train before SMOTE:", len(X_train)
print "num X_test before SMOTE: ", len(X_test)
print "Mean of train target vector:", y_train.mean()
print "Mean of test target vector:", y_test.mean()

# print "NUM null before imputation:", np.count_nonzero(~np.isnan(X_train))
# X_train_fit = predictive_imputer.PredictiveImputer(max_iter=10, initial_strategy='median',
#                                                    f_model="RandomForest").fit(X_train, y_train)
# X_train = X_train_fit.transform(X_train)
# print "NUM null after imputation:", np.count_nonzero(~np.isnan(X_train))
# X_test = X_train_fit.transform(X_test)

#X_train, y_train = SMOTE(kind='borderline1', ratio={True:20000},k_neighbors=13).fit_sample(X_train, y_train)
# use the SMOTE call below
#X_train, y_train = SMOTE(kind='borderline1',k_neighbors=3).fit_sample(X_train, y_train)
#X_train, y_train = NearMiss(random_state=0, version=2).fit_sample(X_train, y_train)

#X_resampled, y_resampled = SMOTE().fit_sample(transformed_X, y)
#X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=42)
print "num X_train:", len(X_train)
print "num X_test: ", len(X_test)
#print "num X_val:", len(X_val)
print "Mean of train target vector:", y_train.mean()
print "Mean of test target vector:", y_test.mean()
# plt.hist(y_train)
# plt.show()
#print "Mean of val target vector:", y_val.mean()
# Out:
# number of operations: 69993
# number of unique admission groups: 65067
# num X_train before SMOTE: 55994
# num X_test before SMOTE:  13999
# Mean of train target vector: 0.019984284030431832
# Mean of test target vector: 0.018287020501464392
# num X_train: 55994
# num X_test:  13999
# Mean of train target vector: 0.019984284030431832
# Mean of test target vector: 0.018287020501464392

# %%
if verbose:
    display(pd.DataFrame(data=X_train, columns=df.columns.values[0:]).describe(include="all"))

# %%
if verbose:
    pd.DataFrame(data=X_train, columns=df.columns.values[0:]).head(10)

# %%
# try:
#     plt.boxplot(X_train[:,0])
#     print transformed_X[np.where(transformed_X[:,df.columns.get_loc("AGE_LT_89")] < 0),0].mean()
#     print np.max(X_train[:,df.columns.get_loc("AGE_LT_89")])
#     print np.max(X_test[:,df.columns.get_loc("AGE_LT_89")])
#     X_train
#     print X_train.shape
#     print X_test.shape

#     print df.columns.get_loc("AGE_LT_89")
#     print np.mean(transformed_X[:,df.columns.get_loc("AGE_LT_89")])
#     print np.mean(X_train[:,df.columns.get_loc("AGE_LT_89")])
#     print np.mean(X_test[:,df.columns.get_loc("AGE_LT_89")])
#     #X_train[df.columns.get_loc("AGE_LT_89")-1].std()
# except KeyError:
#     pass

# %% [markdown]
# ## Standardize training, testing data
#
# Here we standardize the training set, and use the mean/std on the test set

# %%
class StandardizeWithNaN(TransformerMixin, BaseEstimator):
    '''This estimator is for standardizing a dataset that has missing data'''
    def __init__(self):
        self.X_mean = []
        self.X_std = []
        pass

    def fit(self, X, y=None):
        # get mean and standard deviation of columns
        self.X_mean = np.nanmean(X, axis=0)
        self.X_std  = np.nanstd(X, axis=0) 
        return self

    def transform(self, X):
        # subtract mean and divide by standard deviation
        return (X - self.X_mean)/self.X_std

# %%
#scaler = StandardScaler()  
scaler = StandardizeWithNaN()
# Don't cheat - fit only on training data
scaler.fit(X_train)
X_train = scaler.transform(X_train) 
# apply same transformation to test data
X_test = scaler.transform(X_test) 
#X_val = scaler.transform(X_val)

# %%
class SoftImputeEstimator(TransformerMixin, BaseEstimator):
    '''This estimator is for wrapping the SoftImpute algorithm'''
    def __init__(self, max_iters=200, verbose=True):
        self.max_iters = max_iters
        self.verbose = verbose
        self.fit_count = 0
        self.transform_count = 0
        pass

    def fit(self, X, y=None):
        self.fit_count += 1
        print("SoftImputeEstimator fit count: {}".format(self.fit_count))
        return self

    def transform(self, X):
        self.transform_count += 1
        print("SoftImputeEstimator transform count: {}".format(self.transform_count))
        try:
            # subtract mean and divide by standard deviation
            return SoftImpute(max_iters=self.max_iters, verbose=self.verbose).complete(X.replace(np.inf, np.nan))
        # ValueError raised if no values need to be imputed
        except ValueError:
            return np.array(X)

# %%
print("imputing X_train")
si = SoftImputeEstimator()
X_train = si.transform(X_train)
# Out:
# imputing X_train
# SoftImputeEstimator transform count: 1
# [SoftImpute] Max Singular Value of X_init = 236.626288
# [SoftImpute] Iter 1: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 2: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 3: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 4: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 5: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 6: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 7: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 8: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 9: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 10: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 11: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 12: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 13: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 14: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 15: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 16: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 17: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 18: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 19: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 20: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 21: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 22: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 23: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 24: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 25: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 26: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 27: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 28: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 29: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 30: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 31: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 32: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 33: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 34: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 35: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 36: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 37: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 38: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 39: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 40: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 41: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 42: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 43: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 44: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 45: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 46: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 47: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 48: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 49: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 50: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 51: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 52: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 53: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 54: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 55: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 56: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 57: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 58: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 59: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 60: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 61: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 62: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 63: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 64: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 65: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 66: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 67: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 68: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 69: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 70: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 71: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 72: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 73: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 74: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 75: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 76: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 77: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 78: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 79: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 80: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 81: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 82: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 83: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 84: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 85: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 86: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 87: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 88: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 89: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 90: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 91: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 92: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 93: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 94: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 95: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 96: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 97: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 98: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 99: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 100: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 101: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 102: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 103: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 104: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 105: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 106: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 107: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 108: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 109: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 110: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 111: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 112: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 113: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 114: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 115: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 116: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 117: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 118: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 119: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 120: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 121: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 122: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 123: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 124: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 125: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 126: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 127: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 128: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 129: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 130: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 131: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 132: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 133: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 134: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 135: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 136: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 137: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 138: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 139: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 140: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 141: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 142: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 143: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 144: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 145: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 146: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 147: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 148: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 149: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 150: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 151: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 152: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 153: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 154: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 155: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 156: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 157: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 158: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 159: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 160: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 161: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 162: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 163: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 164: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 165: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 166: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 167: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 168: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 169: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 170: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 171: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 172: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 173: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 174: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 175: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 176: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 177: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 178: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 179: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 180: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 181: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 182: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 183: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 184: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 185: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 186: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 187: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 188: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 189: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 190: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 191: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 192: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 193: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 194: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 195: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 196: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 197: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 198: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 199: observed MAE=0.015952 rank=1
# [SoftImpute] Iter 200: observed MAE=0.015952 rank=1
# [SoftImpute] Stopped after iteration 200 for lambda=4.732526

# %%
print("imputing X_test")
#print(np.isnan(X_test).any())
X_test = si.transform(X_test.replace(np.inf, np.nan))
# Out:
# imputing X_test
# SoftImputeEstimator transform count: 2
# [SoftImpute] Max Singular Value of X_init = 118.969980
# [SoftImpute] Iter 1: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 2: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 3: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 4: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 5: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 6: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 7: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 8: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 9: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 10: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 11: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 12: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 13: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 14: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 15: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 16: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 17: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 18: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 19: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 20: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 21: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 22: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 23: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 24: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 25: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 26: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 27: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 28: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 29: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 30: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 31: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 32: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 33: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 34: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 35: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 36: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 37: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 38: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 39: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 40: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 41: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 42: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 43: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 44: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 45: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 46: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 47: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 48: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 49: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 50: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 51: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 52: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 53: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 54: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 55: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 56: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 57: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 58: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 59: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 60: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 61: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 62: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 63: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 64: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 65: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 66: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 67: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 68: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 69: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 70: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 71: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 72: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 73: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 74: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 75: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 76: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 77: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 78: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 79: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 80: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 81: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 82: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 83: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 84: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 85: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 86: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 87: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 88: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 89: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 90: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 91: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 92: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 93: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 94: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 95: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 96: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 97: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 98: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 99: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 100: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 101: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 102: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 103: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 104: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 105: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 106: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 107: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 108: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 109: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 110: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 111: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 112: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 113: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 114: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 115: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 116: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 117: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 118: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 119: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 120: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 121: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 122: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 123: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 124: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 125: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 126: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 127: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 128: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 129: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 130: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 131: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 132: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 133: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 134: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 135: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 136: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 137: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 138: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 139: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 140: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 141: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 142: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 143: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 144: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 145: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 146: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 147: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 148: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 149: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 150: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 151: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 152: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 153: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 154: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 155: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 156: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 157: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 158: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 159: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 160: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 161: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 162: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 163: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 164: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 165: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 166: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 167: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 168: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 169: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 170: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 171: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 172: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 173: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 174: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 175: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 176: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 177: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 178: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 179: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 180: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 181: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 182: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 183: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 184: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 185: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 186: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 187: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 188: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 189: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 190: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 191: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 192: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 193: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 194: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 195: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 196: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 197: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 198: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 199: observed MAE=0.016065 rank=1
# [SoftImpute] Iter 200: observed MAE=0.016065 rank=1
# [SoftImpute] Stopped after iteration 200 for lambda=2.379400

# %%
X_train, y_train = SMOTE(kind='borderline1',k_neighbors=3).fit_sample(X_train, y_train)

# %% [markdown]
# ## Train model(s)
# The code is set up to train/test/evaluate any model added to the *models* list.
#
# To add a model, simply append it to the list, and append a corresponding name
# for the model to the *model_names* list as this will be used for plotting.

# %%
from sklearn.neural_network import MLPClassifier
from sklearn import svm

num_threads = -1

models = []
models_cv = []
model_names = []
cachedir = mkdtemp()
#weight_vec = np.multiply((float(X_train.shape[0]) / (2*np.bincount(y))), [1, 1.2])
#print weight_vec

#scaler = StandardScaler() 
scaler = StandardizeWithNaN()
imp = SoftImputeEstimator(verbose=True)
smt = SMOTE(kind='borderline1', k_neighbors=3)
#smt = NearMiss(random_state=0, version=1)
pipeline_stages = [('scaler', scaler), ('impute', imp), ('smt', smt)]
#pipeline_stages = [('scaler', scaler), ('smt', smt)]

## Logistic Regression
#models.append(LogisticRegression(class_weight="balanced"))
if model_type == "classification":
    #models.append(LogisticRegression(class_weight={0:weight_vec[0], 1:weight_vec[1]} ,n_jobs=-1))
    lrg = LogisticRegression(class_weight="balanced", n_jobs=1)
    models.append(lrg)
    models_cv.append(Pipeline(pipeline_stages + [('lrg', lrg)]))
    model_names.append("Log. Regression")
## ElasticNet
#models.append(ElasticNet(l1_ratio=0.0001, fit_intercept=True))

elasticnet = ElasticNetCV(max_iter=3000, fit_intercept=True, n_jobs=num_threads, cv=5)
elasticnet.fit(X_train, y_train)
en_alpha = elasticnet.alpha_
en_l1_ratio = elasticnet.l1_ratio_
print "ElasticNet alpha:", en_alpha
print "ElasticNet l1_ratio:", en_l1_ratio
# model_names.append("ElasticNetCV")

if model_type == "classification":
    eln = SGDClassifier(loss="log", penalty="elasticnet", alpha=en_alpha, class_weight="balanced",
                                l1_ratio=en_l1_ratio, fit_intercept=True, max_iter=3000, n_jobs=num_threads)
    models.append(eln)
    models_cv.append(Pipeline(pipeline_stages + [('eln', eln)]))
# if model_type == "regression":
#     models.append(ElasticNet(alpha=en_alpha, l1_ratio=en_l1_ratio, fit_intercept=True))
model_names.append("ElasticNet")
## Multilayer Perceptron (MLP)
##models.append(MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(32, 4), early_stopping=True))
#models.append(MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(4, 6), early_stopping=True))
#model_names.append("MLP")

## Random Forest 
if model_type == "classification":
    rfc = RandomForestClassifier(class_weight="balanced", oob_score=True, n_estimators=2000, n_jobs=num_threads, max_features="log2")
#    rfc = RandomForestClassifier(class_weight={1:1.0, 2:1.0, 3:1.1, 4:1.3, 5:1.5}, oob_score=True, n_estimators=2000, n_jobs=-1, max_features="log2")
    models.append(rfc)
    models_cv.append(Pipeline(pipeline_stages + [('rfc', rfc)]))
    model_names.append("Random Forest")
    
    xgb = XGBClassifier(max_depth=5, objective="binary:logistic", n_estimators=2000, n_jobs=num_threads, silent=True)
    models.append(xgb)
    models_cv.append(Pipeline(pipeline_stages + [('xgb', xgb)]))
    model_names.append("XGBClassifier")
    
#     model_name = "10212016_model5_dropcols_wASA_keras2"
#     model_root = "mortmodel_FINAL_pkg/"+model_name+"/"
#     json_file = open(model_root+'model.json', 'r')
#     loaded_model_json = json_file.read()
#     json_file.close()
#     loaded_model = model_from_json(loaded_model_json)
#     layerspec = pickle.load(open(model_root + '/'+'layerspec.p', 'rb'))
#     lrsched = pickle.load(open(model_root + '/' +'lrsched.p', 'rb'))
#     aug_data = pickle.load(open(model_root + '/' + 'augspec.p', 'rb'))
#     print(layerspec)
#     print(lrsched)
#     print(aug_data)
    
#     sgd = SGD(lr=lrsched["learningrate"], momentum=lrsched["momentum"], decay=lrsched["decay"], nesterov=lrsched["Nesterov"])
#     def f():
# #         lm = loaded_model = model_from_json(loaded_model_json)
# #         lm.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])
#         sgd = SGD(lr=0.0001, momentum=0.9, decay=1e-6, nesterov=True)
#         mm = Sequential()
#         mm.add(Dense(units=300, activation='relu', use_bias=True, kernel_initializer="normal", input_dim=287))
#         mm.add(Dropout(rate=0.5))
#         mm.add(Dense(units=100, activation='relu', use_bias=True, kernel_initializer="normal", input_dim=300))
#         mm.add(Dropout(rate=0.5))
# #         mm.add(Dense(units=200, activation='relu', use_bias=True, kernel_initializer="normal", input_dim=300))
# #         mm.add(Dropout(rate=0.5))
#         #mm.add(Dense(units=1, activation='softmax'))
#         mm.add(Dense(units=1, kernel_initializer="normal"))
#         mm.compile(loss='mse', optimizer="adam", metrics=['accuracy', 'mse'])
#         return mm
#     dnn = KerasClassifier(build_fn=f, batch_size=200, epochs=10, verbose=1)
#     models.append(dnn)
#     models_cv.append(Pipeline([('smt', smt), ('scaler', scaler), ('dnn', dnn)]))
#     model_names.append("DNN")

if model_type == "regression":
    models.append(RandomForestRegressor(max_depth=5, oob_score=True, n_estimators=2000, n_jobs=num_threads, max_features="log2"))
    model_names.append("RanfomForestRegressor")
    
    xgb = XGBRegressor(max_depth=7, n_estimators=2000, n_jobs=num_threads)
    models.append(xgb)
    model_names.append("XGBRegressor")
# models.append(GradientBoostingClassifier(n_estimators=1000))
# model_names.append("GradientBoostedClass")
# Out:
# ElasticNet alpha: 0.0003930445117748029
# ElasticNet l1_ratio: 0.5

# %%
mo = []
for mod in models:
    #mod.fit(X_train, y_train, epochs=12, batch_size=200)
    mod.fit(X_train, y_train)
    #cal_mod = CalibratedClassifierCV(mod, cv=5, method="isotonic")
    #cal_mod.fit(X_train, y_train)
    #mo.append(cal_mod)
    
#models = mo
# Out:
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/sklearn/linear_model/stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)

# %% [markdown]
# ## Examine feature relevance

# %%
# import xgboost
# shap.initjs()
# #print df.columns.values
# #xdf = pd.DataFrame(data=X_train, columns=df.columns.values[1:])
# #bst = xgboost.train({"learning_rate": 0.01}, xgboost.DMatrix(xdf, label=y_train), 100)
# #shap_values = bst.predict(xgboost.DMatrix(xdf), pred_contribs=True)
# #shap.force_plot(shap_values[0], xdf[0,:])
# print(type(models[2]))
# shap_values = shap.TreeExplainer(models[2]).shap_values(X_train[1:500, :])
# print shap_values.shape

# %%
# print len(shap_values[1])

# %%
# shap.summary_plot(shap_values, X_train[1:500, :])

# %%
for i in range(len(models)):
    if model_names[i] == 'Random Forest':
        print "Random Forest Feature Importances:"
        display(pd.DataFrame(zip(df.columns.values[0:], np.transpose(models[i].feature_importances_))).sort_values([1], ascending=False))
        pd.DataFrame(zip(df.columns.values[0:], np.transpose(models[i].feature_importances_))).sort_values([1], ascending=False).to_csv(os.path.join(dir_to_save_files, "random_forest_feature_importance.txt"), sep="|", index=False,header=False)
    elif model_names[i] == 'Log. Regression':
        print "Log. Regression Coef. Weights:"
        display(pd.DataFrame(zip(df.columns.values[0:], np.transpose(models[i].coef_[0]))).sort_values([1], ascending=False))
        pd.DataFrame(zip(df.columns.values[0:], np.transpose(models[i].coef_[0]))).sort_values([1], ascending=False).to_csv(os.path.join(dir_to_save_files, "log_reg_feature_importance.txt"), sep="|", index=False,header=False)
    elif model_names[i] == 'ElasticNet':
        print "ElasticNet Coef. Weights:"
        display(pd.DataFrame(zip(df.columns.values[0:], np.transpose(models[i].coef_[0]))).sort_values([1], ascending=False)) 
        pd.DataFrame(zip(df.columns.values[0:], np.transpose(models[i].coef_[0]))).sort_values([1], ascending=False).to_csv(os.path.join(dir_to_save_files, "elasticnet_feature_importance.txt"), sep="|", index=False,header=False)
    elif model_names[i] == 'XGBClassifier':
        print "XGBoost Feature Importances:"
        display(pd.DataFrame(zip(df.columns.values[0:], np.transpose(models[i].feature_importances_))).sort_values([1], ascending=False))
        pd.DataFrame(zip(df.columns.values[0:], np.transpose(models[i].feature_importances_))).sort_values([1], ascending=False).to_csv(os.path.join(dir_to_save_files, "xgboost_feature_importance.txt"), sep="|", index=False,header=False)
# Out:
# Log. Regression Coef. Weights:
#         0         1
# 0  POSPOM  0.732668
# ElasticNet Coef. Weights:
#         0         1
# 0  POSPOM  0.730981
# Random Forest Feature Importances:
#         0    1
# 0  POSPOM  1.0
# XGBoost Feature Importances:
#         0    1
# 0  POSPOM  1.0

# %%
## Create bar plots for feature importance
# fig, ax = plt.subplots(figsize=(10,70))
# eldf = zip(df.columns.values[1:], np.transpose(models[model_names.index("ElasticNet")].coef_[0]))
# eldf = sorted(eldf, key=lambda x: x[1], reverse=False)

# ax.barh(range(len(eldf)), [x[1] for x in eldf])
# ax.set_yticks(np.arange(len(eldf)))
# ax.set_yticklabels([x[0] for x in eldf])
# ax.set_xlabel("Model Weight")
# plt.gca().yaxis.grid(True)
# plt.tight_layout()
# plt.savefig('elasticnet_feature_importance_plot.png', bbox_inches='tight')

# %% [markdown]
# ## Generate class probabilities

# %%
def calibrate_predicted_probability(pred_prob, p_1):
#def calibrate_predicted_probability(pred_prob, orig_freq, oversampled_freq):
    if pred_prob == 0.0: 
        return 0.0
    p_0 = 1.0 - p_1
    #return 1./(1.+((1./orig_freq)-1.)/((1./oversampled_freq)-1.)*((1./pred_prob)-1.))
    # formula below from Christine Lee's paper
    return 1.0/(1.0+((1.0/pred_prob)-1.0)*(p_0/p_1))

calibrate_predicted_probability_vec = np.vectorize(calibrate_predicted_probability)

# %%
#print calibrate_predicted_probability_vec([0.09500048], y_test.mean(), y_train.mean())

def generate_class_probs(models, X_test):
    try:
        # generate class probabilities
        #model_probs = [calibrate_predicted_probability_vec(mod.predict_proba(X_test), y_test.mean()) for mod in models]
        model_probs = [mod.predict_proba(X_test) for mod in models]
        #probs = model2.predict(X_test)
        #print model_probs
    except AttributeError:
        pass
    return model_probs

model_probs = generate_class_probs(models, np.array(X_test))

# %%
# death_indices = [i for i,x in enumerate(y_test) if x]
# print model_probs[2][death_indices][:,1]
# plt.hist(model_probs[2][:,1], bins=100, density=True)

# %% [markdown]
# ## Predict class labels & plot mean square error

# %%
# predict class labels for the test set
def predict_given_threshold(probs, threshold=0.15):
    return [True if x[1] > threshold else False for x in probs]

#model_predictions = [np.rint(mod.predict(X_test)) for mod in models]
#model_predictions = [predict_given_threshold(probs, y_test.mean()) for probs in model_probs]
model_predictions = [mod.predict(np.array(X_test)) for mod in models]
print model_predictions[0][0:10]
print model_probs[0][0:10]
print y_test[0:10]
#print np.rint(model_predictions[0][0:10])
#mse = [metrics.mean_squared_error(y_test, predicted) for predicted in model_predictions]
#print [x[1] for x in model_probs[0]]

# def plot_mean_square_error(models, model_names, mse):
#     print "Mean Square Error:"
#     for i in range(len(models)):
#         print model_names[i],"\t\t", mse[i]

#     plt.figure(figsize=default_size)
#     plt.gca().yaxis.grid(True)
#     plt.bar(np.arange(len(models)), mse, align='center')
#     plt.xticks(np.arange(len(models)), model_names)
#     plt.xlabel('Classifier')
#     plt.ylabel('Mean Square Error (MSE)')
#     plt.title('Classifier MSE')
#     plt.legend(loc="lower right")
#     plt.show()
    
#plot_mean_square_error(models, model_names, mse)
#print metrics.mean_squared_error(y_test, [x[1] for x in model_probs[0]])
# Out:
# [False False  True False False False False False False False]
# [[0.59719149 0.40280851]
#  [0.59719149 0.40280851]
#  [0.31249242 0.68750758]
#  [0.77230367 0.22769633]
#  [0.56845482 0.43154518]
#  [0.56845482 0.43154518]
#  [0.59719149 0.40280851]
#  [0.70405528 0.29594472]
#  [0.53924976 0.46075024]
#  [0.53924976 0.46075024]]
# [False False False False False False False False False False]

# %% [markdown]
# ## Calculate accuracy and AUC

# %%
# def plot_accuracy_roc_auc(models, model_names, model_predictions, model_probs, y_train, y_test, filename):
#     # generate evaluation metrics
#     model_acc = [metrics.accuracy_score(y_test, preds) for preds in model_predictions]
#     model_roc_auc = [metrics.roc_auc_score(y_test, probs[:,1]) for probs in model_probs]
#     model_avg_precision = [metrics.average_precision_score(y_test, probs[:,1]) for probs in model_probs]

#     fig, ax = plt.subplots(figsize=(8,8))
#     index = np.arange(len(models))
#     bar_width = 0.35
#     opacity = 0.8

#     rects1 = plt.bar(index, model_acc, bar_width,
#                      alpha=opacity,
#                      color=PLOT_COLOURS[0],
#                      label='Accuracy')

#     rects2 = plt.bar(index + bar_width, model_roc_auc, bar_width,
#                      alpha=opacity,
#                      color=PLOT_COLOURS[1],
#                      label='ROC AUC')
    
#     rects3 = plt.bar(index + 2*bar_width, model_avg_precision, bar_width,
#                      alpha=opacity,
#                      color=PLOT_COLOURS[2],
#                      label='Avg. Precision')

#     plt.xlabel('Model')
#     plt.ylabel('Score')
#     plt.title('Model Accuracy/ROC AUC/Avg. Precision')
#     plt.xticks(index + bar_width, model_names)
#     plt.legend(loc="lower right")
#     plt.gca().yaxis.grid(True)
#     plt.ylim([0.0, 1.05])
#     plt.plot([1.0 - y_train.mean()]*(len(models)), color=PLOT_COLOURS[3], lw=2, linestyle='--')
#     plt.tight_layout()
#     #plt.savefig(os.path.join(dir_to_save_files, filename), format="tif", dpi=fig_dpi)
#     plt.show()

#     for i in range(len(models)):
#         print model_names[i], "Accuracy:\t\t", metrics.accuracy_score(y_test, model_predictions[i])
#         print model_names[i], "ROC AUC:\t\t", metrics.roc_auc_score(y_test, model_probs[i][:, 1])
#         print model_names[i], "Avg. Precision:\t\t", metrics.average_precision_score(y_test, model_probs[i][:, 1])
   
plot_accuracy_roc_auc(models, model_names, model_predictions, model_probs, y_train, y_test, "accuracy_roc_auc.png")
# Out:
# Log. Regression Accuracy:		0.6729766411886563
# Log. Regression ROC AUC:		0.6836234526213345
# Log. Regression Avg. Precision:		0.03474597080397615
# ElasticNet Accuracy:		0.6729766411886563
# ElasticNet ROC AUC:		0.6836234526213345
# ElasticNet Avg. Precision:		0.03474597080397615
# Random Forest Accuracy:		0.7766983355953997
# Random Forest ROC AUC:		0.6156828987939315
# Random Forest Avg. Precision:		0.024127683215935673
# XGBClassifier Accuracy:		0.7766269019215658
# XGBClassifier ROC AUC:		0.6157346296751072
# XGBClassifier Avg. Precision:		0.024128042866954615

# %% [markdown]
# ## Plot ROC curve

# %%
# def plot_roc_curve(models, model_names, model_probs, y_test, filename):
#     print(default_size)
#     plt.figure(figsize=default_size)
#     lw = 2
#     for i in range(len(models)):
#         fpr, tpr, _ = metrics.roc_curve(y_test, model_probs[i][:, 1])
#         roc_auc = metrics.auc(fpr, tpr)
#         plt.plot(fpr, tpr, PLOT_COLOURS[i], lw=lw, label=model_names[i]+' ROC curve (area = %0.4f)' % roc_auc)
#     #plt.plot(fpr, tpr, color='darkorange',
#     #         lw=lw, label='ROC curve (area = %0.4f)' % roc_auc)
#     plt.plot([0, 1], [0, 1], color='black', lw=lw, linestyle='--')
#     plt.xlim([0.0, 1.0])
#     plt.ylim([0.0, 1.05])
#     plt.yticks(np.arange(0., 1.1, 0.1))
#     plt.xticks(np.arange(0., 1.0, 0.1))
#     ax = plt.axes()
#     ax.tick_params(direction='out', length=6, width=2, colors='black')
#     plt.xlabel('False Positive Rate')
#     plt.ylabel('True Positive Rate')
#     plt.title('Receiver Operating Characteristic')
#     plt.legend(loc="lower right")
#     plt.savefig(os.path.join(dir_to_save_files, filename), format="tif", dpi=fig_dpi)
#     plt.show()
    
plot_roc_curve(models, model_names, model_probs, y_test, os.path.join(dir_to_save_files,"roc_curve.png"))
# Out:
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# def confusion_matrix_classification_rpt(models, model_names, model_predictions, y_test):
#     for i in range(len(models)):
# #         precision, recall, f1, support = metrics.precision_recall_fscore_support(y_test, model_predictions[i], average='binary')
# #         tn, fp, fn, tp = metrics.confusion_matrix(y_test, model_predictions[i]).ravel()
#         print "=================================================="
#         print "MODEL: ", model_names[i]
# #         print "precision:\t", precision
# #         print "recall:\t\t", recall
# #         print "specificity:\t", float(tn) / (tn + fp)
# #         print "F1:\t\t", f1
# #         print "Support:\t", support
#         print metrics.confusion_matrix(y_test, model_predictions[i])
#         pd.DataFrame(metrics.confusion_matrix(y_test, model_predictions[i])).to_csv(
#             os.path.join(dir_to_save_files, model_names[i].lower().replace(" ", "_") + "_confusion_matrix.txt"), sep='|', header=False, index=False)
# #         print "TN:", tn, "FP:", fp, "FN:", fn, "TP:", tp
#         print metrics.classification_report(y_test, model_predictions[i], digits=4)
        
confusion_matrix_classification_rpt(models, model_names, model_predictions, y_test, dir_to_save_files)
# Out:
# ==================================================
# MODEL:  Log. Regression
# [[9271 4472]
#  [ 106  150]]
#               precision    recall  f1-score   support
#
#        False     0.9887    0.6746    0.8020     13743
#         True     0.0325    0.5859    0.0615       256
#
#    micro avg     0.6730    0.6730    0.6730     13999
#    macro avg     0.5106    0.6303    0.4317     13999
# weighted avg     0.9712    0.6730    0.7884     13999
#
# ==================================================
# MODEL:  ElasticNet
# [[9271 4472]
#  [ 106  150]]
#               precision    recall  f1-score   support
#
#        False     0.9887    0.6746    0.8020     13743
#         True     0.0325    0.5859    0.0615       256
#
#    micro avg     0.6730    0.6730    0.6730     13999
#    macro avg     0.5106    0.6303    0.4317     13999
# weighted avg     0.9712    0.6730    0.7884     13999
#
# ==================================================
# MODEL:  Random Forest
# [[10823  2920]
#  [  206    50]]
#               precision    recall  f1-score   support
#
#        False     0.9813    0.7875    0.8738     13743
#         True     0.0168    0.1953    0.0310       256
#
#    micro avg     0.7767    0.7767    0.7767     13999
#    macro avg     0.4991    0.4914    0.4524     13999
# weighted avg     0.9637    0.7767    0.8584     13999
#
# ==================================================
# MODEL:  XGBClassifier
# [[10822  2921]
#  [  206    50]]
#               precision    recall  f1-score   support
#
#        False     0.9813    0.7875    0.8738     13743
#         True     0.0168    0.1953    0.0310       256
#
#    micro avg     0.7766    0.7766    0.7766     13999
#    macro avg     0.4991    0.4914    0.4524     13999
# weighted avg     0.9637    0.7766    0.8584     13999

# %% [markdown]
# ## Plot precision-recall curve

# %%
#average_precision = average_precision_score(y_test, predicted)
#print('Average precision-recall score: {0:0.4f}'.format(
#      average_precision))
# def plot_precision_recall_curve(models, model_names, model_probs, y_test, filename):
#     plt.figure(figsize=(7,7))
#     for i in range(len(models)):
#         precision, recall, thresholds = precision_recall_curve(y_test, model_probs[i][:, 1])
#         pr_auc = metrics.auc(recall, precision)
#         plt.step(recall, precision, PLOT_COLOURS[i], alpha=0.7,
#              where='post', label=model_names[i]+' PR curve (area = %0.4f)' % pr_auc)
#         plt.fill_between(recall, precision, step='post', alpha=0.2,
#                      )

#     plt.xlabel('Recall')
#     plt.ylabel('Precision')
#     plt.ylim([0.0, 1.05])
#     plt.yticks(np.arange(0., 1.1, 0.1))
#     ax = plt.axes()
#     ax.tick_params(direction='out', length=6, width=2, colors='black')
#     plt.xlim([0.0, 1.05])
#     plt.xticks(np.arange(0., 1.1, 0.1))
#     plt.title('Precision-Recall curve')
#     plt.legend(loc="upper right")
#     plt.savefig(os.path.join(dir_to_save_files, filename), format="tif", dpi=fig_dpi)
#     plt.show()
from ehr_utils import *
plot_precision_recall_curve(models, model_names, model_probs, y_test, os.path.join(dir_to_save_files, "precision_recall_curve.png"))
# Out:
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## Plot calibration curves

# %%
# plot derived from: http://scikit-learn.org/stable/auto_examples/calibration/plot_compare_calibration.html#sphx-glr-auto-examples-calibration-plot-compare-calibration-py
plt.figure(figsize=(10, 10))
ax1 = plt.subplot2grid((3, 1), (0, 0), rowspan=2)
ax2 = plt.subplot2grid((3, 1), (2, 0))

ax1.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
for i in range(len(models)):
    #clf.fit(X_train, y_train)
    #if hasattr(models[i], "predict_proba"):
    #    prob_pos = clf.predict_proba(X_test)[:, 1]
    #else:  # use decision function
        #prob_pos = clf.decision_function(X_test)
        #prob_pos = \
        #    (prob_pos - prob_pos.min()) / (prob_pos.max() - prob_pos.min())
    calibrated_model_probs = [calibrate_predicted_probability(j, y_test.mean()) for j in model_probs[i][:, 1]]
    print model_probs[i][:, 1][0:7]
    print calibrated_model_probs[0:7]
    #calibrated_model_probs = calibrate_predicted_probability_vec(model_probs[i][:, 1], y_test.mean(), y_train.mean())
    fraction_of_positives, mean_predicted_value = \
        calibration_curve(y_test, calibrated_model_probs, n_bins=10)

    ax1.plot(mean_predicted_value, fraction_of_positives, PLOT_COLOURS[i], "s-",
             label="%s" % (model_names[i], ))

    ax2.hist(model_probs[i], range=(0, 1), bins=10, label=model_names[i],
             histtype="step", lw=2)

ax1.set_ylabel("Fraction of positives")
ax1.set_ylim([-0.05, 1.05])
ax1.legend(loc="upper left")
ax1.set_title('Calibration plots  (reliability curve)')

ax2.set_xlabel("Mean predicted value")
ax2.set_ylabel("Count")
ax2.legend(loc="upper center", ncol=2)

plt.tight_layout()
plt.savefig(os.path.join(dir_to_save_files, "calibration_plots.tif"), format="tif", dpi=fig_dpi)
plt.show()
# Out:
# [0.40280851 0.40280851 0.68750758 0.22769633 0.43154518 0.43154518
#  0.40280851]
# [0.012408542268928735, 0.012408542268928735, 0.039368880522410686, 0.005461950509620139, 0.013944093175370596, 0.013944093175370596, 0.012408542268928735]
# [0.40302827 0.40302827 0.68711861 0.22819258 0.43170247 0.43170247
#  0.40302827]
# [0.012419741518178566, 0.012419741518178566, 0.039300490850937835, 0.005477289405982217, 0.013952911428545918, 0.013952911428545918, 0.012419741518178566]
# [0.02547533 0.02547533 0.88705689 0.00131493 0.02500591 0.02500591
#  0.02547533]
# [0.000486714237986831, 0.000486714237986831, 0.12762951423854335, 2.4525669109290957e-05, 0.00047752003151427957, 0.00047752003151427957, 0.000486714237986831]
# [0.02546066 0.02546066 0.8871116  0.00132188 0.02495052 0.02495052
#  0.02546066]
# [0.0004864267361610231, 0.0004864267361610231, 0.12769034413148855, 2.4655522905350205e-05, 0.00047643580070769404, 0.00047643580070769404, 0.0004864267361610231]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-b1fe069b57b1> in <module>()
#      35
#      36 plt.tight_layout()
# ---> 37 plt.savefig(os.path.join(dir_to_save_files, "calibration_plots.tif"), format="tif", dpi=fig_dpi)
#      38 plt.show()
#
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/pyplot.pyc in savefig(*args, **kwargs)
#     693 def savefig(*args, **kwargs):
#     694     fig = gcf()
# --> 695     res = fig.savefig(*args, **kwargs)
#     696     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     697     return res
#
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/figure.pyc in savefig(self, fname, **kwargs)
#    2060             self.set_frameon(frameon)
#    2061
# -> 2062         self.canvas.print_figure(fname, **kwargs)
#    2063
#    2064         if frameon:
#
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2171
#    2172         # get canvas object and print method for format
# -> 2173         canvas = self._get_output_canvas(format)
#    2174         print_method = getattr(canvas, 'print_%s' % format)
#    2175
#
# /home/blhill/anaconda3/envs/preop/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _get_output_canvas(self, fmt)
#    2103         raise ValueError(
#    2104             "Format {!r} is not supported (supported formats: {})"
# -> 2105             .format(fmt, ", ".join(sorted(self.get_supported_filetypes()))))
#    2106
#    2107     def print_figure(self, filename, dpi=None, facecolor=None, edgecolor=None,
#
# ValueError: Format 'tif' is not supported (supported formats: eps, pdf, pgf, png, ps, raw, rgba, svg, svgz)

# %% [markdown]
# # Calculate Brier Score Loss

# %%
print "Brier Score Loss:"
for i in range(len(models)):
    
    brier_loss = brier_score_loss(y_test, model_probs[i][:, 1])
    print model_names[i],"\t\t", brier_loss

# %% [markdown]
# ## Cross Validation of Model Metrics

# %%
num_folds = 5

group_by_admsn = admsn_ids.astype('category').cat.codes
print "number of operations:", len(group_by_admsn)
print "number of unique admission groups:", len(np.unique(group_by_admsn))
group_kfold = GroupKFold(n_splits=num_folds)

# save GroupKFold object as pickle object
pickle.dump(group_kfold, open( os.path.join(dir_to_save_files, "group_kfold.p"), "wb" ))

# %%
# keep track of these during cross-validation
model_probs_cv = []
model_preds_cv = []
testing_labels_cv = []
admsn_ids_cv = []
or_case_ids_cv = []
test_index_cv = []
admsn_surgery_num_cv = []
for model in model_names:
    model_probs_cv.append([])
    model_preds_cv.append([])
    testing_labels_cv.append([])

cv_num = 1
for train_index, test_index in group_kfold.split(np.array(df.iloc[:,0:]), y, group_by_admsn):
    X_train, X_test = df.iloc[train_index], df.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    # keep track of these for writing to file
    admsn_ids_cv = admsn_ids_cv + list(admsn_ids.iloc[test_index])
    or_case_ids_cv = or_case_ids_cv + list(or_case_id_number.iloc[test_index])
    admsn_surgery_num_cv = admsn_surgery_num_cv + list(admsn_surgery_number.iloc[test_index])
    test_index_cv = test_index_cv + [cv_num] * len(list(test_index))
    
    print "admsn_ids_cv len:", len(admsn_ids_cv)
    print "or_case_ids_cv len:", len(or_case_ids_cv)
    print "admsn_surgery_num_cv len:", len(admsn_surgery_num_cv)
    print "test_index_cv len:", len(test_index_cv)
    
    # scale the training and testing data
    scaler = StandardizeWithNaN()
    # fit on training data
    scaler.fit(X_train)
    X_train = scaler.transform(X_train) 
    # apply same transformation to test data
    X_test = scaler.transform(X_test) 
    
    print("imputing X_train")
    si = SoftImputeEstimator(verbose=False)
    X_train = si.transform(X_train)
    print("imputing X_test")
    X_test = si.transform(X_test.replace(np.inf, np.nan))
    
    # oversample the training dataset
    X_train, y_train = SMOTE(kind='borderline1',k_neighbors=3).fit_sample(X_train, y_train)
    
    i = 0
    for mod in models:
        print("fitting {} model".format(model_names[i]))
        mod.fit(X_train, y_train)
        print("finished fitting...")
        model_probs = mod.predict_proba(np.array(X_test))
        model_predictions = mod.predict(np.array(X_test))
        model_probs_cv[i].append(model_probs)
        model_preds_cv[i].append(model_predictions)
        testing_labels_cv[i].append(y_test)
        i += 1
    cv_num += 1

# %%
# calculate model performance metrics and save to file

def tp(y_true, y_pred): return metrics.confusion_matrix(y_true, y_pred)[1, 1]
def tn(y_true, y_pred): return metrics.confusion_matrix(y_true, y_pred)[0, 0]
def fp(y_true, y_pred): return metrics.confusion_matrix(y_true, y_pred)[0, 1]
def fn(y_true, y_pred): return metrics.confusion_matrix(y_true, y_pred)[1, 0]

def ci(results):
    return st.t.interval(0.95, len(results)-1, loc=np.mean(results), scale=st.sem(results))

metrics_dict = {}
metric_string = "{:0.3f} ({:0.3f}-{:0.3f})"

for i in range(len(model_names)):
    metrics_dict[model_names[i]] = []
    
    model_probs = model_probs_cv[i]
    model_preds = model_preds_cv[i]
    y_test = testing_labels_cv[i]
    
    tp_vec = [tp(y_true, y_pred) for (y_true, y_pred) in zip(y_test, model_preds)]
    tn_vec = [tn(y_true, y_pred) for (y_true, y_pred) in zip(y_test, model_preds)]
    fp_vec = [fp(y_true, y_pred) for (y_true, y_pred) in zip(y_test, model_preds)]
    fn_vec = [fn(y_true, y_pred) for (y_true, y_pred) in zip(y_test, model_preds)]
    
    fpr_vec = np.array([metrics.roc_curve(y_true, probs[:, 1])[0] for (y_true, probs) in zip(y_test, model_probs)])
    tpr_vec = np.array([metrics.roc_curve(y_true, probs[:, 1])[1] for (y_true, probs) in zip(y_test, model_probs)])
    roc_auc_vec = np.array([metrics.auc(fpr, tpr) for (fpr, tpr) in zip(fpr_vec, tpr_vec)])
    precision_vec = np.array([metrics.precision_score(y_true, y_pred) for (y_true, y_pred) in zip (y_test, model_preds)])
    recall_vec = np.array([metrics.recall_score(y_true, y_pred) for (y_true, y_pred) in zip (y_test, model_preds)])
    f1_vec = np.array([metrics.f1_score(y_true, y_pred) for (y_true, y_pred) in zip (y_test, model_preds)])
    accuracy_vec = np.array([metrics.accuracy_score(y_true, y_pred) for (y_true, y_pred) in zip (y_test, model_preds)])
    specificity_vec = np.array([(float(t_n)/(t_n + f_p)) for (t_n, f_p) in zip(tn_vec, fp_vec)])
    print "=================================================="
    print "MODEL: ", model_names[i]
    print "ROC AUC:\t", metric_string.format(roc_auc_vec.mean(), ci(roc_auc_vec)[0], ci(roc_auc_vec)[1])
    print "specificity:\t", metric_string.format(specificity_vec.mean(), ci(specificity_vec)[0], ci(specificity_vec)[1])
    print "precision:\t", metric_string.format(precision_vec.mean(), ci(precision_vec)[0], ci(precision_vec)[1])
    print "recall:\t\t", metric_string.format(recall_vec.mean(), ci(recall_vec)[0], ci(recall_vec)[1])
    print "f1 score:\t", metric_string.format(f1_vec.mean(), ci(f1_vec)[0], ci(f1_vec)[1])
    print "accuracy:\t", metric_string.format(accuracy_vec.mean(), ci(accuracy_vec)[0], ci(accuracy_vec)[1])
    
    metrics_dict[model_names[i]].append(metric_string.format(roc_auc_vec.mean(), ci(roc_auc_vec)[0], ci(roc_auc_vec)[1]))
    metrics_dict[model_names[i]].append(metric_string.format(specificity_vec.mean(), ci(specificity_vec)[0], ci(specificity_vec)[1]))
    metrics_dict[model_names[i]].append(metric_string.format(precision_vec.mean(), ci(precision_vec)[0], ci(precision_vec)[1]))
    metrics_dict[model_names[i]].append(metric_string.format(recall_vec.mean(), ci(recall_vec)[0], ci(recall_vec)[1]))
    metrics_dict[model_names[i]].append(metric_string.format(f1_vec.mean(), ci(f1_vec)[0], ci(f1_vec)[1]))
    metrics_dict[model_names[i]].append(metric_string.format(accuracy_vec.mean(), ci(accuracy_vec)[0], ci(accuracy_vec)[1]))
    
metrics_df = pd.DataFrame.from_dict(metrics_dict, orient="index")
metrics_df.columns =["ROC AUC", "Specificity", "Precision", "Recall", "F1 Score", "Accuracy"]
metrics_df.head()
metrics_df.to_csv(os.path.join(dir_to_save_files, "model_scores_manual_cv.txt"), sep=",", header=True, index=True)

# %%
model_probs_dict = {"OR_CASE_ID": or_case_ids_cv,
                    "ADMSN_ID": admsn_ids_cv, 
                    "ADMSN_SURGERY_NUMBER": admsn_surgery_num_cv, 
                    "test_index": test_index_cv,
                    TARGET_VARIABLE: []}

for model_name in model_names:
    model_probs_dict[model_name] = []

for j in range(group_kfold.get_n_splits()):
    for i in range(len(model_names)):
        print(len(model_probs_cv[i][j]))
        model_probs_dict[model_names[i]] = model_probs_dict[model_names[i]] + list(model_probs_cv[i][j][:,1])
        if i == 0:
            model_probs_dict[TARGET_VARIABLE] = model_probs_dict[TARGET_VARIABLE] + list(testing_labels_cv[i][j])
            
for k,v in model_probs_dict.iteritems():
    print k, len(v)
            
model_probs_df = pd.DataFrame(data=model_probs_dict)
model_probs_df.to_csv(os.path.join(dir_to_save_files, "model_pred_probs_v2.txt"), sep="\t", header=True, index=False)
if verbose:
    model_probs_df.head()

# %%
foobar baz

# %%
# take the first fold of the k-fold split
# train_index, test_index = group_kfold.split(transformed_X, y, group_by_admsn).next()
# X_train, X_test = transformed_X[train_index], transformed_X[test_index]
# y_train, y_test = y[train_index], y[test_index]

# ddd = {"OR_CASE_ID": or_case_id_number,
#        "ADMSN_ID": admsn_ids, 
#        "ADMSN_SURGERY_NUMBER": admsn_surgery_number,
#        "INPT_DEATH_YN": y}

cv = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)
model_probs_cv = []
model_count = 0
for model in models_cv:
    print("starting model", model_count)
    probs = cross_val_predict(model, df.iloc[:,0:], y, 
                      cv=group_kfold.split(df.iloc[:,0:], y, group_by_admsn), 
                      n_jobs=1, method='predict_proba', verbose=3) 
    print("finished model", model_count)
#     ddd[model_names[model_count]] = model_probs_cv[model_count][:,1]
#     new_df = pd.DataFrame(data=ddd)
#     new_df.to_csv(os.path.join(dir_to_save_files, "model_pred_probs.txt"), sep="\t", header=True, index=False)
    model_count += 1
    model_probs_cv.append(probs)

#model_probs_cv = [cross_val_predict(model, df.iloc[:,0:], y, cv=group_kfold.split(df.iloc[:,0:], y, group_by_admsn), n_jobs=5, method='predict_proba') for model in models_cv]

# %%
# ddd = {"ADMSN_ID": admsn_ids, 
#        "PRED_DEATH_LOGREG": model_probs_cv[0][:,1], 
#        "PRED_DEATH_ELASTICNET": model_probs_cv[1][:,1], 
#        "PRED_DEATH_RF": model_probs_cv[2][:,1],
#        "PRED_DEATH_XGB": model_probs_cv[3][:,1],
#        "INPT_DEATH_YN": y}
ddd = {"OR_CASE_ID": or_case_id_number,
       "ADMSN_ID": admsn_ids, 
       "ADMSN_SURGERY_NUMBER": admsn_surgery_number,
       TARGET_VARIABLE: y}
for i in range(len(model_names)):
    ddd[model_names[i]] = model_probs_cv[i][:,1]
new_df = pd.DataFrame(data=ddd)
new_df.to_csv(os.path.join(dir_to_save_files, "model_pred_probs.txt"), sep="\t", header=True, index=False)

# %%
# new_df.sort_values(by=["ADMSN_ID", "ADMSN_SURGERY_NUMBER"], inplace=True)
# new_df.head(5)
# print new_df.shape

# %%
# print admsn_ids.shape
# print transformed_X.shape
# lldf = pd.DataFrame(data=np.concatenate((np.expand_dims(admsn_ids, axis=1), transformed_X), axis=1), columns=["ADMSN_ID"] + list(df.columns.values))

# %%
# total_admissions = new_df["ADMSN_ID"].nunique()
# num_mult_admission = 0
# num_live_increase_risk_2nd_surgery = 0
# num_live_increase_risk_last_surgery = 0

# num_death = 0
# num_death_increase_risk_2nd_surgery = 0
# num_death_increase_risk_last_surgery = 0

# for name,group in new_df.groupby("ADMSN_ID"):
# #     print name[0:10]
# #     print group.shape
#     # if we have patients with multiple surgeries
#     if group.shape[0] > 1:
#         num_mult_admission += 1
#         #print group
#         if group["INPT_DEATH_YN"].iloc[0] == False:
#             # check if risk increased from first to second surgery
#             if group["PRED_DEATH_RF"].iloc[1] > group["PRED_DEATH_RF"].iloc[0]:
#                 num_live_increase_risk_2nd_surgery += 1
#             # check if risk increased from first to last surgery
#             if group["PRED_DEATH_RF"].iloc[-1] > group["PRED_DEATH_RF"].iloc[0]:
#                 num_live_increase_risk_last_surgery += 1
#         else:
#             num_death += 1
#             # check if risk increased from first to second surgery
#             if group["PRED_DEATH_RF"].iloc[1] > group["PRED_DEATH_RF"].iloc[0]:
#                 num_death_increase_risk_2nd_surgery += 1
#             # check if risk increased from first to last surgery
#             if group["PRED_DEATH_RF"].iloc[-1] > group["PRED_DEATH_RF"].iloc[0]:
#                 num_death_increase_risk_last_surgery += 1
            
# print "total admissions:", total_admissions
# print "number of deaths: {} ({}%)".format(num_death, num_death * 100. / total_admissions)
# print "number of survivors that increased in risk from 1st to 2nd surgery: {} ({}%)".format(
#     num_live_increase_risk_2nd_surgery, num_live_increase_risk_2nd_surgery * 100. / (num_mult_admission-num_death))
# print "number of survivors that increased in risk from 1st to LAST surgery: {} ({}%)".format(
#     num_live_increase_risk_last_surgery, num_live_increase_risk_last_surgery * 100. / (num_mult_admission-num_death))
# print "number of deaths that increased in risk from 1st to 2nd surgery: {} ({}%)".format(
#     num_death_increase_risk_2nd_surgery, num_death_increase_risk_2nd_surgery * 100. / num_death)
# print "number of deaths that increased in risk from 1st to LAST surgery: {} ({}%)".format(
#     num_death_increase_risk_last_surgery, num_death_increase_risk_last_surgery * 100. / num_death)

# i = 0
# plt.hold(True)
# for name,group in new_df.groupby("ADMSN_ID"):
# #     print name[0:10]
# #     print group.shape
#     # if we have patients with multiple surgeries
#     if group.shape[0] > 1:
#         #print group
#         plot_color = 'b' if group["INPT_DEATH_YN"].iloc[0] == False else 'r'
#         if group["INPT_DEATH_YN"].iloc[0] == False:
#             plt.plot(range(group.shape[0]), group["PRED_DEATH_RF"], plot_color)
#             i = i+1
#         if i > 100: 
#             break
# i = 0
# for name,group in new_df.groupby("ADMSN_ID"):
# #     print name[0:10]
# #     print group.shape
#     # if we have patients with multiple surgeries
#     if group.shape[0] > 1:
#         #print group
#         plot_color = 'b' if group["INPT_DEATH_YN"].iloc[0] == False else 'r'
#         if group["INPT_DEATH_YN"].iloc[0] == True:
#             plt.plot(range(group.shape[0]), group["PRED_DEATH_RF"], plot_color)
#             i = i+1
#         if i > 100: 
#             break
# plt.title("Change in mortality prediction over multiple surgeries")
# plt.xlabel("Surgery Number")
# plt.ylabel("P(death)")
# plt.show()

# %%
plot_roc_curve(models, model_names, model_probs_cv, y, os.path.join(dir_to_save_files, "roc_curve_cv.tif"))

# %%
plot_precision_recall_curve(models, model_names, model_probs_cv, y, os.path.join(dir_to_save_files, "precision_recall_cv.tif"))

# %%
print "Brier Score Loss:"
with open(os.path.join(dir_to_save_files, "brier_score_cv.txt"), "w") as text_file:
    for i in range(len(models)):
        brier_loss = brier_score_loss(y, model_probs_cv[i][:, 1])
        print model_names[i],"\t\t", brier_loss
        text_file.write("{},{}\n".format(model_names[i], brier_loss))

# %%
num_folds = 5

# group_by_admsn = admsn_ids.astype('category').cat.codes
# print "number of operations:", len(group_by_admsn)
# print "number of unique admission groups:", len(np.unique(group_by_admsn))
# group_kfold = GroupKFold(n_splits=num_folds)

#cv = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

def tp(y_true, y_pred): return metrics.confusion_matrix(y_true, y_pred)[1, 1]
def tn(y_true, y_pred): return metrics.confusion_matrix(y_true, y_pred)[0, 0]
def fp(y_true, y_pred): return metrics.confusion_matrix(y_true, y_pred)[0, 1]
def fn(y_true, y_pred): return metrics.confusion_matrix(y_true, y_pred)[1, 0]

scoring = {'tp' : make_scorer(tp), 'tn' : make_scorer(tn),
           'fp' : make_scorer(fp), 'fn' : make_scorer(fn),
            'accuracy': 'accuracy', 'roc_auc': 'roc_auc',
             'average_precision': 'average_precision',
          'precision': 'precision', 'recall': 'recall',
          'f1_score': 'f1'}

#scoring = ['accuracy', 'roc_auc', 'average_precision']
# model_scores_cv = [cross_validate(model, df.iloc[:,0:], y, scoring=scoring, 
#                                   cv=group_kfold.split(df.iloc[:,0:], y, group_by_admsn), 
#                                   n_jobs=1, verbose=2) for model in models_cv]

model_scores_cv = []
model_count = 0
for model in models_cv:
    print("starting model", model_count)
#     print(model.named_steps)
    mod_scores = cross_validate(model, df.iloc[:,0:], y, scoring=scoring, 
                                  cv=group_kfold.split(df.iloc[:,0:], y, group_by_admsn), 
                                  n_jobs=1, verbose=10)
    print("finished model", model_count)
    model_count += 1
    model_scores_cv.append(mod_scores)

# model_accuracy_cv = [cross_val_score(model, X_train, y_train, 
#                                    scoring='accuracy', cv=cv, n_jobs=-1) for model in models]
# model_roc_auc_cv = [cross_val_score(model, X_train, y_train, 
#                                    scoring='roc_auc', cv=cv, n_jobs=-1) for model in models]
# model_avg_precision_cv = [cross_val_score(model, X_train, y_train, 
#                                    scoring='average_precision', cv=cv, n_jobs=-1) for model in models]
print model_scores_cv

# %%
fig, ax = plt.subplots(figsize=default_size)
index = np.arange(len(models))
bar_width = 0.35
opacity = 0.8
 
rects1 = plt.bar(index, [m['test_accuracy'].mean() for m in model_scores_cv], bar_width,
                 alpha=opacity,
                 color=PLOT_COLOURS[0],
                 yerr=[np.std(m['test_accuracy']) for m in model_scores_cv],
                 label='Mean Accuracy')
 
rects2 = plt.bar(index + bar_width, [m['test_roc_auc'].mean() for m in model_scores_cv], bar_width,
                 alpha=opacity,
                 color=PLOT_COLOURS[1],
                 yerr=[np.std(m['test_roc_auc']) for m in model_scores_cv],
                 label='Mean ROC AUC')

rects3 = plt.bar(index + 2*bar_width, [m['test_average_precision'].mean() for m in model_scores_cv], bar_width,
                 alpha=opacity,
                 color=PLOT_COLOURS[2],
                 yerr=[np.std(m['test_average_precision']) for m in model_scores_cv],
                 label='Mean Avg. Precision')

 
plt.xlabel('Model')
plt.ylabel('Score')
plt.title('Model Accuracy/ROC AUC/Avg. Precision with ASA_STATUS (CV=%d)' % num_folds)
plt.xticks(index + bar_width, model_names)
plt.ylim([0.0, 1.05])
plt.yticks(np.arange(0., 1.1, 0.05))
plt.legend(loc="lower right")
plt.gca().yaxis.grid(True)
plt.plot([1.0 - y_test.mean()]*(len(models)), color='red', lw=2, linestyle='--')
plt.tight_layout()
plt.savefig(os.path.join(dir_to_save_files, "accuracy_roc_auc_cv.tif"), format="tif", dpi=fig_dpi)
plt.show()

# %%
def ci(results):
    return st.t.interval(0.95, len(results)-1, loc=np.mean(results), scale=st.sem(results))

# %%
with open(os.path.join(dir_to_save_files, "model_scores_cv.txt"), "w") as text_file:
    text_file.write("Model," + ",".join(scoring.keys()) + ",specificity" + "\n")
    for mod in model_names:
        print "Model:", mod
        text_file.write(mod + ",")
        for score in scoring.keys():
            score_vals = model_scores_cv[model_names.index(mod)]['test_' + score]
            print "\t", score, "\t{:0.3f} ({:0.3f}-{:0.3f})".format(score_vals.mean(), ci(score_vals)[0], ci(score_vals)[1])
            text_file.write("{:0.3f} ({:0.3f}-{:0.3f}),".format(score_vals.mean(), ci(score_vals)[0], ci(score_vals)[1]))
            #print "mod:", mod, "score:", score

        tn = model_scores_cv[model_names.index(mod)]['test_tn']
        fp = model_scores_cv[model_names.index(mod)]['test_fp']
        specificity_vals = np.array(tn, dtype="float") / (np.array(tn) + np.array(fp))
        print "\tspecificity:\t", "\t{:0.3f} ({:0.3f}-{:0.3f})".format(specificity_vals.mean(), ci(specificity_vals)[0], ci(specificity_vals)[1])
        text_file.write("{:0.3f} ({:0.3f}-{:0.3f})\n".format(specificity_vals.mean(), ci(specificity_vals)[0], ci(specificity_vals)[1]))
        precision_vals = score_vals = model_scores_cv[model_names.index(mod)]['test_precision']
        recall_vals = score_vals = model_scores_cv[model_names.index(mod)]['test_recall']
        f1_score_vals = np.nan_to_num(2.0*(precision_vals*recall_vals)/(precision_vals + recall_vals))
        print "\tf1 score:\t", "\t{:0.3f} ({:0.3f}-{:0.3f})".format(f1_score_vals.mean(), ci(f1_score_vals)[0], ci(f1_score_vals)[1])
        #text_file.write("\t{:0.3f} ({:0.3f}-{:0.3f})\n".format(f1_score_vals.mean(), ci(f1_score_vals)[0], ci(f1_score_vals)[1]))

# %%
rf_cv_auc = model_scores_cv[model_names.index('Random Forest')]['test_roc_auc']
print "Random Forest CV AUC", rf_cv_auc
print rf_cv_auc.mean()
print ci(rf_cv_auc)
rf_cv_precision = model_scores_cv[model_names.index('Random Forest')]['test_precision']
print "Random Forest CV Precision", rf_cv_precision
print rf_cv_precision.mean()
print ci(rf_cv_precision)

# %%
en_cv_auc = model_scores_cv[model_names.index('ElasticNet')]['test_roc_auc']
print "ElasticNet CV AUC", en_cv_auc
print en_cv_auc.mean()
print ci(en_cv_auc)

# %%
lr_cv_auc = model_scores_cv[model_names.index('Log. Regression')]['test_roc_auc']
print "Log. Regression CV AUC", lr_cv_auc
print lr_cv_auc.mean()
print ci(lr_cv_auc)

# %%
lr_cv_auc = model_scores_cv[model_names.index('XGBClassifier')]['test_roc_auc']
print "XGBClassifier CV AUC", lr_cv_auc
print lr_cv_auc.mean()
print ci(lr_cv_auc)

# %%
######################################################
# Code for imputing ASA status
######################################################

#scaler = StandardScaler() 
scaler = StandardizeWithNaN()
imp = SoftImputeEstimator(verbose=True)
smt = SMOTE(kind='borderline1', k_neighbors=3)

cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
#rfr = RandomForestRegressor(oob_score=True, n_estimators=2000, n_jobs=1, max_features="log2")
rfr = XGBRegressor(max_depth=7, n_estimators=2000, n_jobs=-1)
rfr_pipe = Pipeline([('scaler', scaler), ('impute', imp), ('smt', smt), ('rfr', rfr)])
asa_predictions = cross_val_predict(rfr_pipe, df.iloc[:,0:], y, cv=group_kfold.split(df.iloc[:,0:], y, group_by_admsn), n_jobs=1)
#xgb = XGBClassifier(max_depth=5, objective="binary:logistic", n_estimators=2000, n_jobs=-1)
#xgb_pipe = Pipeline([('smt', smt), ('scaler', scaler), ('rfr', xgb)])
#asa_predictions = cross_val_predict(xgb_pipe, transformed_X, y, cv=cv, n_jobs=5, method='predict_proba')

# %%
print "Number of predictions:", len(asa_predictions)
print df.shape
print asa_predictions[0:10]

# %%
print y[0:10]

# %%
input_death_yn[0:10]
death_indices = [i for i,x in enumerate(input_death_yn) if x]
live_indices = [i for i,x in enumerate(input_death_yn) if not x]
print death_indices[0:10]
print len(death_indices)
print len(live_indices)

# %%
print asa_predictions[death_indices]
print y[death_indices]

# %%
plt.scatter(y[death_indices], asa_predictions[death_indices])
plt.xlabel("True ASA_STATUS")
plt.ylabel("Predicted ASA_STATUS")

# %%
from sklearn.metrics import mean_squared_error, r2_score
print mean_squared_error(y[death_indices], asa_predictions[death_indices])
print r2_score(y[death_indices], asa_predictions[death_indices])

# %%
plt.scatter(y[live_indices], asa_predictions[live_indices])
plt.xlabel("True ASA_STATUS")
plt.ylabel("Predicted ASA_STATUS")

# %%
from sklearn.metrics import mean_squared_error, r2_score
print mean_squared_error(y[live_indices], asa_predictions[live_indices])
print r2_score(y[live_indices], asa_predictions[live_indices])

# %%
ddd = {"ADMSN_ID": admsn_ids, "OR_CASE_ID": or_case_id_number, "PRED_ASA_STATUS": asa_predictions, "ASA_STATUS": y}
#ddd = {"ADMSN_ID": admsn_ids, "PRED_DEATH": asa_predictions[:,1], "INPT_DEATH_YN": y}
#ddd = {"ADMSN_ID": admsn_ids, "PRED_AKIN_EVENT": model_probs_cv[2][:,1], "AKIN_EVENT": y}
#ddd = {"ADMSN_ID": admsn_ids, "PRED_DEATH": model_probs_cv[2][:,1], "INPT_DEATH_YN": y}

# %%
print len(y)
print len(admsn_ids)
#print len(model_probs_cv[2][:,1])
new_df = pd.DataFrame(data=ddd)
print df.shape

#print len(asa_predictions)

# %%
new_df.boxplot(column="PRED_ASA_STATUS", by="ASA_STATUS")
plt.title("")
plt.suptitle("")
plt.ylabel("PRED_ASA_STATUS")

# %%
new_df.head(30)

# %%
new_df.to_csv(os.path.join(dir_to_save_files, "ASA_predictions_noTime.txt"), sep="\t", header=True, index=False)
if False:
    #pass
    new_df.to_csv("AKIN_EVENT_predictions.txt", sep="\t", header=True, index=False)

# %%
new_df.describe(include="all")
